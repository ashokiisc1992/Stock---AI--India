# %%
# Day 6 — Additions to Weekly Report
import pandas as pd
import numpy as np
import yfinance as yf
import pickle
import warnings
warnings.filterwarnings('ignore')

# Load all existing data
with open('../data/price_data.pkl', 'rb') as f:
    price_data = pickle.load(f)

with open('../data/indicator_data.pkl', 'rb') as f:
    indicator_data = pickle.load(f)

fund_df    = pd.read_csv('../data/fundamental_scores.csv')
tech_df    = pd.read_csv('../data/technical_report.csv')

print(f"Price data     : {len(price_data)} stocks")
print(f"Indicator data : {len(indicator_data)} stocks")
print(f"Fundamental    : {len(fund_df)} stocks")
print(f"Tech report    : {len(tech_df)} stocks")
print(f"\nColumns in tech_df:")
print(tech_df.columns.tolist())
# Out:
# D:\installations\anaconda\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# D:\installations\anaconda\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (
# Price data     : 35 stocks
# Indicator data : 35 stocks
# Fundamental    : 35 stocks
# Tech report    : 35 stocks
#
# Columns in tech_df:
# ['Symbol', 'Sector', 'Fund Score', 'Current Price', 'RSI', 'ADX', 'MACD Hist', 'Vol Ratio', 'EMA20', 'EMA50', 'EMA200', 'DI+', 'DI-', 'Momentum Score', 'Reversal Score', 'Best Setup', 'Tech Score', 'Tier', 'In Consolidation', 'Consol Days', 'Consol Label', 'Pct to Breakout', 'Consol Volume', 'Sector Score', 'Cap Score', 'Market Cap Cr', 'Cap Category']

# %%
# ── TASK 1: VOLUME INFERENCE ────────────────────────────────────────────────

def get_volume_inference(row):
    vol   = float(row['Vol Ratio'])
    setup = str(row['Best Setup'])
    rsi   = float(row['RSI'])
    adx   = float(row['ADX'])

    if   vol >= 2.0: vol_label = "Very High"
    elif vol >= 1.5: vol_label = "High"
    elif vol >= 1.0: vol_label = "Normal"
    elif vol >= 0.7: vol_label = "Low"
    else:            vol_label = "Very Low"

    # ── Momentum ──────────────────────────────────────────────────────────────
    if setup == 'Momentum':
        if   vol >= 2.0: return vol_label, "Strong participation → trend likely to continue"
        elif vol >= 1.5: return vol_label, "Good volume support → momentum confirmed"
        elif vol >= 1.0: return vol_label, "Average volume → monitor for increase"
        elif vol >= 0.7: return vol_label, "Weak volume → momentum may fade, wait"
        else:            return vol_label, "Very low volume → no conviction, caution"

    # ── Reversal ──────────────────────────────────────────────────────────────
    elif setup == 'Reversal':
        if   vol <= 0.5: return vol_label, "Sellers exhausted → reversal likely"
        elif vol <= 0.7: return vol_label, "Low volume on down move → selling pressure easing"
        elif vol <= 1.0: return vol_label, "Neutral volume → wait for low-volume base to form"
        elif vol <= 1.5: return vol_label, "Elevated volume on reversal → watch direction"
        else:            return vol_label, "High volume → could be capitulation or distribution"

    # ── Watching / Waiting ────────────────────────────────────────────────────
    else:
        if   adx > 40 and vol >= 1.5: return vol_label, "High volume downtrend → stay away"
        elif adx > 40:                return vol_label, "Strong downtrend → no entry signal"
        elif vol <= 0.5:              return vol_label, "Very low volume → no interest, wait"
        elif vol >= 1.5 and rsi < 35: return vol_label, "High volume selloff → possible capitulation"
        elif vol >= 1.5:              return vol_label, "Above avg volume but no setup → watch"
        else:                         return vol_label, "Low activity → no setup forming yet"


# ── Test ─────────────────────────────────────────────────────────────────────
print(f"{'Symbol':12} {'Setup':10} {'Vol':5}  {'Label':10}  Inference")
print("─" * 78)
for _, row in tech_df.iterrows():
    label, inference = get_volume_inference(row)
    print(f"  {row['Symbol']:12} {row['Best Setup']:10} "
          f"{row['Vol Ratio']:.2f}x  {label:10}  {inference}")
# Out:
# Symbol       Setup      Vol    Label       Inference
# ──────────────────────────────────────────────────────────────────────────────
#   TCS          Watching   0.61x  Very Low    Strong downtrend → no entry signal
#   RELIANCE     Watching   1.09x  Normal      Low activity → no setup forming yet
#   WIPRO        Reversal   0.69x  Very Low    Low volume on down move → selling pressure easing
#   PERSISTENT   Reversal   0.49x  Very Low    Sellers exhausted → reversal likely
#   LTTS         Reversal   10.78x  Very High   High volume → could be capitulation or distribution
#   HAPPSTMNDS   Momentum   0.72x  Low         Weak volume → momentum may fade, wait
#   CHOLAFIN     Watching   0.85x  Low         Strong downtrend → no entry signal
#   MUTHOOTFIN   Watching   1.17x  Normal      Strong downtrend → no entry signal
#   MANAPPURAM   Watching   0.64x  Very Low    Strong downtrend → no entry signal
#   CREDITACC    Reversal   0.73x  Low         Neutral volume → wait for low-volume base to form
#   GARFIBRES    Reversal   3.65x  Very High   High volume → could be capitulation or distribution
#   SUPRAJIT     Reversal   0.78x  Low         Neutral volume → wait for low-volume base to form
#   HIMATSEIDE   Watching   1.39x  Normal      Strong downtrend → no entry signal
#   HAL          Watching   1.12x  Normal      Low activity → no setup forming yet
#   BEL          Watching   1.05x  Normal      Low activity → no setup forming yet
#   MIDHANI      Watching   1.22x  Normal      Low activity → no setup forming yet
#   PARAS        Watching   0.28x  Very Low    Very low volume → no interest, wait
#   VINATIORGA   Reversal   1.56x  High        High volume → could be capitulation or distribution
#   FINEORG      Reversal   0.44x  Very Low    Sellers exhausted → reversal likely
#   GALAXYSURF   Watching   1.29x  Normal      Low activity → no setup forming yet
#   AAVAS        Watching   0.64x  Very Low    Strong downtrend → no entry signal
#   SUNPHARMA    Momentum   1.05x  Normal      Average volume → monitor for increase
#   DIVISLAB     Watching   0.75x  Low         Low activity → no setup forming yet
#   APLLTD       Reversal   0.79x  Low         Neutral volume → wait for low-volume base to form
#   GRANULES     Watching   0.71x  Low         Low activity → no setup forming yet
#   IPCALAB      Momentum   2.91x  Very High   Strong participation → trend likely to continue
#   TITAN        Watching   1.35x  Normal      Low activity → no setup forming yet
#   HAVELLS      Reversal   2.26x  Very High   High volume → could be capitulation or distribution
#   VGUARD       Watching   1.85x  High        Above avg volume but no setup → watch
#   SYMPHONY     Watching   0.70x  Low         Low activity → no setup forming yet
#   WONDERLA     Momentum   1.14x  Normal      Average volume → monitor for increase
#   PIIND        Watching   1.13x  Normal      Low activity → no setup forming yet
#   RALLIS       Watching   0.49x  Very Low    Very low volume → no interest, wait
#   DHANUKA      Watching   0.84x  Low         Low activity → no setup forming yet
#   ABSLAMC      Momentum   0.44x  Very Low    Very low volume → no conviction, caution

# %%
# ── Add Vol Inference columns to tech_df ─────────────────────────────────────
tech_df['Vol Label']     = ''
tech_df['Vol Inference'] = ''

for idx, row in tech_df.iterrows():
    label, inference = get_volume_inference(row)
    tech_df.at[idx, 'Vol Label']     = label
    tech_df.at[idx, 'Vol Inference'] = inference

# ── Verify ────────────────────────────────────────────────────────────────────
print("Added to tech_df:")
print(tech_df[['Symbol', 'Best Setup', 'Vol Ratio',
               'Vol Label', 'Vol Inference']].to_string(index=False))
# Out:
# Added to tech_df:
#     Symbol Best Setup  Vol Ratio Vol Label                                       Vol Inference
#        TCS   Watching       0.61  Very Low                  Strong downtrend → no entry signal
#   RELIANCE   Watching       1.09    Normal                 Low activity → no setup forming yet
#      WIPRO   Reversal       0.69  Very Low   Low volume on down move → selling pressure easing
# PERSISTENT   Reversal       0.49  Very Low                 Sellers exhausted → reversal likely
#       LTTS   Reversal      10.78 Very High High volume → could be capitulation or distribution
# HAPPSTMNDS   Momentum       0.72       Low               Weak volume → momentum may fade, wait
#   CHOLAFIN   Watching       0.85       Low                  Strong downtrend → no entry signal
# MUTHOOTFIN   Watching       1.17    Normal                  Strong downtrend → no entry signal
# MANAPPURAM   Watching       0.64  Very Low                  Strong downtrend → no entry signal
#  CREDITACC   Reversal       0.73       Low   Neutral volume → wait for low-volume base to form
#  GARFIBRES   Reversal       3.65 Very High High volume → could be capitulation or distribution
#   SUPRAJIT   Reversal       0.78       Low   Neutral volume → wait for low-volume base to form
# HIMATSEIDE   Watching       1.39    Normal                  Strong downtrend → no entry signal
#        HAL   Watching       1.12    Normal                 Low activity → no setup forming yet
#        BEL   Watching       1.05    Normal                 Low activity → no setup forming yet
#    MIDHANI   Watching       1.22    Normal                 Low activity → no setup forming yet
#      PARAS   Watching       0.28  Very Low                 Very low volume → no interest, wait
# VINATIORGA   Reversal       1.56      High High volume → could be capitulation or distribution
#    FINEORG   Reversal       0.44  Very Low                 Sellers exhausted → reversal likely
# GALAXYSURF   Watching       1.29    Normal                 Low activity → no setup forming yet
#      AAVAS   Watching       0.64  Very Low                  Strong downtrend → no entry signal
#  SUNPHARMA   Momentum       1.05    Normal               Average volume → monitor for increase
#   DIVISLAB   Watching       0.75       Low                 Low activity → no setup forming yet
#     APLLTD   Reversal       0.79       Low   Neutral volume → wait for low-volume base to form
#   GRANULES   Watching       0.71       Low                 Low activity → no setup forming yet
#    IPCALAB   Momentum       2.91 Very High     Strong participation → trend likely to continue
#      TITAN   Watching       1.35    Normal                 Low activity → no setup forming yet
#    HAVELLS   Reversal       2.26 Very High High volume → could be capitulation or distribution
#     VGUARD   Watching       1.85      High               Above avg volume but no setup → watch
#   SYMPHONY   Watching       0.70       Low                 Low activity → no setup forming yet
#   WONDERLA   Momentum       1.14    Normal               Average volume → monitor for increase
#      PIIND   Watching       1.13    Normal                 Low activity → no setup forming yet
#     RALLIS   Watching       0.49  Very Low                 Very low volume → no interest, wait
#    DHANUKA   Watching       0.84       Low                 Low activity → no setup forming yet
#    ABSLAMC   Momentum       0.44  Very Low            Very low volume → no conviction, caution

# %%
# ── COMPLETE SECTOR → NIFTY INDEX MAP ─────────────────────────────────────────
# Primary: NSE sectoral indices (^CNX...)
# Fallback: Nippon India ETFs (.NS) where index not available on yfinance

SECTOR_INDEX_MAP = {
    # ── Your 35 stocks sectors ─────────────────────────────────────────────────
    'Information Technology'             : '^CNXIT',
    'Healthcare'                         : '^CNXPHARMA',
    'Financial Services'                 : 'FINIETF.NS',    # ETF fallback (^CNXFIN failed)
    'Capital Goods'                      : '^CNXINFRA',
    'Chemicals'                          : 'CHEMIETF.NS',   # ETF fallback (^CNXCHEM failed)
    'Consumer Durables'                  : '^CNXCONSUM',
    'Oil, Gas & Consumable Fuels'        : '^CNXENERGY',
    'Automobile and Auto Components'     : '^CNXAUTO',
    'Textiles'                           : 'MID150BEES.NS', # ETF fallback (no index)
    'Consumer Services'                  : 'MID150BEES.NS', # ETF fallback

    # ── Additional sectors for Day 8 ──────────────────────────────────────────
    'Banking'                            : '^NSEBANK',
    'Private Banking'                    : 'PVTBANIETF.NS', # ETF fallback (^CNXPVTBANK failed)
    'PSU Banking'                        : '^CNXPSUBANK',
    'Fast Moving Consumer Goods'         : '^CNXFMCG',
    'Metals & Mining'                    : '^CNXMETAL',
    'Realty'                             : '^CNXREALTY',
    'Media Entertainment & Publication'  : '^CNXMEDIA',
    'Pharma'                             : '^CNXPHARMA',
    'Services'                           : '^CNXSERVICE',
    'Construction'                       : '^CNXINFRA',
    'Power'                              : '^CNXENERGY',
    'Defence'                            : 'MID150BEES.NS', # no dedicated index/ETF
    'Telecommunication'                  : 'MID150BEES.NS',
    'Diversified'                        : 'MID150BEES.NS',
    'Forest Materials'                   : 'MID150BEES.NS',
    'Agriculture'                        : 'MID150BEES.NS',
    'Cement'                             : '^CNXCMDT',
}

# ── Fetch data ─────────────────────────────────────────────────────────────────
print("Fetching sector index/ETF data...")
sector_price   = {}
ticker_data    = {}
unique_tickers = list(set(SECTOR_INDEX_MAP.values()))

for ticker in unique_tickers:
    try:
        df = yf.Ticker(ticker).history(period='1y')
        if len(df) > 50:
            ticker_data[ticker] = df
            print(f"  ✅ {ticker:20} {len(df)} days")
        else:
            print(f"  ⚠  {ticker:20} only {len(df)} days — FAILED")
    except Exception as e:
        print(f"  ❌ {ticker:20} ERROR: {e}")

# ── Map sector → price data ────────────────────────────────────────────────────
fallback = 'MID150BEES.NS'   # broad midcap ETF as last resort
for sector, ticker in SECTOR_INDEX_MAP.items():
    if ticker in ticker_data:
        sector_price[sector] = ticker_data[ticker]
    elif fallback in ticker_data:
        sector_price[sector] = ticker_data[fallback]
        print(f"  ⚠  {sector} → using MID150BEES fallback")

print(f"\nUnique tickers fetched : {len(ticker_data)}")
print(f"Sectors mapped         : {len(sector_price)}/{len(SECTOR_INDEX_MAP)}")
# Out:
# Fetching sector index/ETF data...
#   ✅ ^CNXAUTO             246 days
#   ✅ ^CNXPHARMA           246 days
#   ✅ ^CNXMEDIA            246 days
#   ✅ ^CNXCMDT             246 days
#   ✅ ^CNXCONSUM           246 days
#   ✅ PVTBANIETF.NS        247 days
#   ✅ ^CNXENERGY           246 days
#   ✅ FINIETF.NS           247 days
#   ✅ MID150BEES.NS        247 days
# $CHEMIETF.NS: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#   ⚠  CHEMIETF.NS          only 0 days — FAILED
#   ✅ ^CNXINFRA            246 days
#   ✅ ^CNXPSUBANK          246 days
#   ✅ ^CNXREALTY           246 days
#   ✅ ^CNXSERVICE          246 days
#   ✅ ^CNXIT               247 days
#   ✅ ^NSEBANK             247 days
#   ✅ ^CNXMETAL            246 days
#   ✅ ^CNXFMCG             246 days
#   ⚠  Chemicals → using MID150BEES fallback
#
# Unique tickers fetched : 17
# Sectors mapped         : 27/27

# %%
# ── Fix Chemicals — try Kotak Chemicals ETF ───────────────────────────────────
print("Testing Kotak Nifty Chemicals ETF...")
chem_df = yf.Ticker('KOTAKCHEMETF.NS').history(period='1y')
print(f"KOTAKCHEMETF.NS: {len(chem_df)} days")

if len(chem_df) > 50:
    ticker_data['KOTAKCHEMETF.NS'] = chem_df
    # Update Chemicals mapping
    for sector in ['Chemicals']:
        sector_price[sector] = chem_df
    print("✅ Chemicals → KOTAKCHEMETF.NS")
else:
    print("⚠  KOTAKCHEMETF.NS failed — Chemicals stays on MID150BEES fallback")
    print("   (acceptable — MID150BEES is broad midcap, chemicals are midcap heavy)")

# ── Final sector coverage summary ─────────────────────────────────────────────
print(f"\nFinal sector coverage: {len(sector_price)}/27")
for sector, df in sector_price.items():
    ticker = SECTOR_INDEX_MAP[sector]
    source = ticker if ticker in ticker_data else 'MID150BEES fallback'
    print(f"  {sector:40} {source}")
# Out:
# Testing Kotak Nifty Chemicals ETF...
# $KOTAKCHEMETF.NS: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# KOTAKCHEMETF.NS: 0 days
# ⚠  KOTAKCHEMETF.NS failed — Chemicals stays on MID150BEES fallback
#    (acceptable — MID150BEES is broad midcap, chemicals are midcap heavy)
#
# Final sector coverage: 27/27
#   Information Technology                   ^CNXIT
#   Healthcare                               ^CNXPHARMA
#   Financial Services                       FINIETF.NS
#   Capital Goods                            ^CNXINFRA
#   Chemicals                                MID150BEES fallback
#   Consumer Durables                        ^CNXCONSUM
#   Oil, Gas & Consumable Fuels              ^CNXENERGY
#   Automobile and Auto Components           ^CNXAUTO
#   Textiles                                 MID150BEES.NS
#   Consumer Services                        MID150BEES.NS
#   Banking                                  ^NSEBANK
#   Private Banking                          PVTBANIETF.NS
#   PSU Banking                              ^CNXPSUBANK
#   Fast Moving Consumer Goods               ^CNXFMCG
#   Metals & Mining                          ^CNXMETAL
#   Realty                                   ^CNXREALTY
#   Media Entertainment & Publication        ^CNXMEDIA
#   Pharma                                   ^CNXPHARMA
#   Services                                 ^CNXSERVICE
#   Construction                             ^CNXINFRA
#   Power                                    ^CNXENERGY
#   Defence                                  MID150BEES.NS
#   Telecommunication                        MID150BEES.NS
#   Diversified                              MID150BEES.NS
#   Forest Materials                         MID150BEES.NS
#   Agriculture                              MID150BEES.NS
#   Cement                                   ^CNXCMDT

# %%
# ── Calculate indicators on sector indices ────────────────────────────────────
def calculate_sector_indicators(df):
    data = df.copy()

    # EMA
    data['EMA20']  = data['Close'].ewm(span=20,  adjust=False).mean()
    data['EMA50']  = data['Close'].ewm(span=50,  adjust=False).mean()
    data['EMA200'] = data['Close'].ewm(span=200, adjust=False).mean()

    # RSI
    delta    = data['Close'].diff()
    gain     = delta.where(delta > 0, 0)
    loss     = -delta.where(delta < 0, 0)
    avg_gain = gain.ewm(span=14, adjust=False).mean()
    avg_loss = loss.ewm(span=14, adjust=False).mean()
    rs       = avg_gain / (avg_loss + 1e-9)
    data['RSI'] = 100 - (100 / (1 + rs))

    # MACD
    ema12          = data['Close'].ewm(span=12, adjust=False).mean()
    ema26          = data['Close'].ewm(span=26, adjust=False).mean()
    data['MACD']   = ema12 - ema26
    data['Signal'] = data['MACD'].ewm(span=9, adjust=False).mean()
    data['MACD_Hist'] = data['MACD'] - data['Signal']

    # ADX
    high     = data['High']
    low      = data['Low']
    close    = data['Close']
    tr1      = high - low
    tr2      = (high - close.shift()).abs()
    tr3      = (low  - close.shift()).abs()
    tr       = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)
    dm_plus  = high.diff()
    dm_minus = -low.diff()
    dm_plus  = dm_plus.where((dm_plus > dm_minus) & (dm_plus > 0), 0)
    dm_minus = dm_minus.where((dm_minus > dm_plus) & (dm_minus > 0), 0)
    atr      = tr.ewm(span=14, adjust=False).mean()
    di_plus  = 100 * dm_plus.ewm(span=14, adjust=False).mean() / (atr + 1e-9)
    di_minus = 100 * dm_minus.ewm(span=14, adjust=False).mean() / (atr + 1e-9)
    dx       = 100 * (di_plus - di_minus).abs() / (di_plus + di_minus + 1e-9)
    data['ADX']      = dx.ewm(span=14, adjust=False).mean()
    data['DI_Plus']  = di_plus
    data['DI_Minus'] = di_minus

    return data


# ── Get sector trend label ─────────────────────────────────────────────────────
def get_sector_trend(sector):
    if sector not in sector_price:
        return "No Data", "N/A | N/A | N/A"

    df     = calculate_sector_indicators(sector_price[sector])
    latest = df.iloc[-1]

    close    = latest['Close']
    rsi      = round(latest['RSI'],      1)
    adx      = round(latest['ADX'],      1)
    ema20    = latest['EMA20']
    ema50    = latest['EMA50']
    ema200   = latest['EMA200']
    di_plus  = latest['DI_Plus']
    di_minus = latest['DI_Minus']
    macd_h   = latest['MACD_Hist']

    above_ema200 = close > ema200
    above_ema50  = close > ema50
    uptrend      = di_plus > di_minus
    strong       = adx > 25

    # Trend label
    if above_ema200 and above_ema50 and strong and uptrend and rsi > 55:
        label = "Strong Uptrend ↑"
    elif above_ema200 and uptrend and rsi > 50:
        label = "Uptrend ↑"
    elif above_ema200 and not strong:
        label = "Weak Uptrend →"
    elif not above_ema200 and not strong and rsi > 45:
        label = "Sideways →"
    elif not above_ema200 and strong and not uptrend and rsi < 45:
        label = "Downtrend ↓"
    elif not above_ema200 and strong and not uptrend and rsi < 35:
        label = "Strong Downtrend ↓"
    else:
        label = "Weak Downtrend ↓"

    ema_status = "Above EMA200" if above_ema200 else "Below EMA200"
    detail     = f"RSI {rsi} | ADX {adx} | {ema_status}"

    return label, detail


# ── Test all sectors in your 35 stocks ────────────────────────────────────────
sectors_in_use = tech_df['Sector'].unique()
print(f"{'Sector':40} {'Trend':20} Detail")
print("─" * 85)
for sector in sorted(sectors_in_use):
    label, detail = get_sector_trend(sector)
    print(f"  {sector:40} {label:20} {detail}")
# Out:
# Sector                                   Trend                Detail
# ─────────────────────────────────────────────────────────────────────────────────────
#   Automobile and Auto Components           Downtrend ↓          RSI 28.7 | ADX 41.4 | Below EMA200
#   Capital Goods                            Downtrend ↓          RSI 21.6 | ADX 42.2 | Below EMA200
#   Chemicals                                Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   Consumer Durables                        Downtrend ↓          RSI 28.0 | ADX 49.1 | Below EMA200
#   Consumer Services                        Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   Financial Services                       Downtrend ↓          RSI 35.7 | ADX 32.0 | Below EMA200
#   Healthcare                               Weak Uptrend →       RSI 37.4 | ADX 22.1 | Above EMA200
#   Information Technology                   Downtrend ↓          RSI 10.3 | ADX 65.3 | Below EMA200
#   Oil, Gas & Consumable Fuels              Weak Uptrend →       RSI 40.8 | ADX 19.8 | Above EMA200
#   Textiles                                 Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200

# %%
# ── Add Sector Trend columns to tech_df ───────────────────────────────────────
tech_df['Sector Trend']  = ''
tech_df['Sector Detail'] = ''

for idx, row in tech_df.iterrows():
    label, detail = get_sector_trend(row['Sector'])
    tech_df.at[idx, 'Sector Trend']  = label
    tech_df.at[idx, 'Sector Detail'] = detail

# ── Verify ────────────────────────────────────────────────────────────────────
print(f"{'Symbol':12} {'Sector':35} {'Trend':20} Detail")
print("─" * 90)
for _, row in tech_df.iterrows():
    print(f"  {row['Symbol']:12} {row['Sector']:35} "
          f"{row['Sector Trend']:20} {row['Sector Detail']}")
# Out:
# Symbol       Sector                              Trend                Detail
# ──────────────────────────────────────────────────────────────────────────────────────────
#   TCS          Information Technology              Downtrend ↓          RSI 10.3 | ADX 65.3 | Below EMA200
#   RELIANCE     Oil, Gas & Consumable Fuels         Weak Uptrend →       RSI 40.8 | ADX 19.8 | Above EMA200
#   WIPRO        Information Technology              Downtrend ↓          RSI 10.3 | ADX 65.3 | Below EMA200
#   PERSISTENT   Information Technology              Downtrend ↓          RSI 10.3 | ADX 65.3 | Below EMA200
#   LTTS         Information Technology              Downtrend ↓          RSI 10.3 | ADX 65.3 | Below EMA200
#   HAPPSTMNDS   Information Technology              Downtrend ↓          RSI 10.3 | ADX 65.3 | Below EMA200
#   CHOLAFIN     Financial Services                  Downtrend ↓          RSI 35.7 | ADX 32.0 | Below EMA200
#   MUTHOOTFIN   Financial Services                  Downtrend ↓          RSI 35.7 | ADX 32.0 | Below EMA200
#   MANAPPURAM   Financial Services                  Downtrend ↓          RSI 35.7 | ADX 32.0 | Below EMA200
#   CREDITACC    Financial Services                  Downtrend ↓          RSI 35.7 | ADX 32.0 | Below EMA200
#   GARFIBRES    Textiles                            Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   SUPRAJIT     Automobile and Auto Components      Downtrend ↓          RSI 28.7 | ADX 41.4 | Below EMA200
#   HIMATSEIDE   Textiles                            Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   HAL          Capital Goods                       Downtrend ↓          RSI 21.6 | ADX 42.2 | Below EMA200
#   BEL          Capital Goods                       Downtrend ↓          RSI 21.6 | ADX 42.2 | Below EMA200
#   MIDHANI      Capital Goods                       Downtrend ↓          RSI 21.6 | ADX 42.2 | Below EMA200
#   PARAS        Capital Goods                       Downtrend ↓          RSI 21.6 | ADX 42.2 | Below EMA200
#   VINATIORGA   Chemicals                           Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   FINEORG      Chemicals                           Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   GALAXYSURF   Chemicals                           Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   AAVAS        Financial Services                  Downtrend ↓          RSI 35.7 | ADX 32.0 | Below EMA200
#   SUNPHARMA    Healthcare                          Weak Uptrend →       RSI 37.4 | ADX 22.1 | Above EMA200
#   DIVISLAB     Healthcare                          Weak Uptrend →       RSI 37.4 | ADX 22.1 | Above EMA200
#   APLLTD       Healthcare                          Weak Uptrend →       RSI 37.4 | ADX 22.1 | Above EMA200
#   GRANULES     Healthcare                          Weak Uptrend →       RSI 37.4 | ADX 22.1 | Above EMA200
#   IPCALAB      Healthcare                          Weak Uptrend →       RSI 37.4 | ADX 22.1 | Above EMA200
#   TITAN        Consumer Durables                   Downtrend ↓          RSI 28.0 | ADX 49.1 | Below EMA200
#   HAVELLS      Consumer Durables                   Downtrend ↓          RSI 28.0 | ADX 49.1 | Below EMA200
#   VGUARD       Consumer Durables                   Downtrend ↓          RSI 28.0 | ADX 49.1 | Below EMA200
#   SYMPHONY     Consumer Durables                   Downtrend ↓          RSI 28.0 | ADX 49.1 | Below EMA200
#   WONDERLA     Consumer Services                   Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   PIIND        Chemicals                           Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   RALLIS       Chemicals                           Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   DHANUKA      Chemicals                           Downtrend ↓          RSI 22.6 | ADX 45.2 | Below EMA200
#   ABSLAMC      Financial Services                  Downtrend ↓          RSI 35.7 | ADX 32.0 | Below EMA200

# %%
# ══════════════════════════════════════════════════════════════════════════════
# COMPLETE WEEKLY REPORT — WITH VOLUME INFERENCE + SECTOR TREND
# ══════════════════════════════════════════════════════════════════════════════

from datetime import datetime

def classify_mcap(mcap_cr):
    if   mcap_cr >= 20000: return 'Large Cap'
    elif mcap_cr >= 10000: return 'Mini Large Cap'
    elif mcap_cr >= 2000:  return 'Mid Cap'
    else:                  return 'Small Cap'

def get_reason(row):
    rsi    = float(row['RSI'])
    adx    = float(row['ADX'])
    setup  = str(row['Best Setup'])
    hist   = float(row['MACD Hist'])
    di_p   = float(row.get('DI+', 0))
    di_m   = float(row.get('DI-', 0))
    ema50  = float(row.get('EMA50',  0))
    ema200 = float(row.get('EMA200', 0))
    price  = float(row.get('Current Price', 0))

    uptrend   = (adx > 25 and di_p > di_m and
                 price > ema50 and price > ema200)
    bounce    = (price > ema50 and price < ema200)
    downtrend = (price < ema200) or (adx > 25 and di_m > di_p)

    if setup == 'Momentum':
        if uptrend:
            return f"Uptrend confirmed, RSI {rsi:.0f}, ADX {adx:.0f}"
        elif bounce:
            return f"Short bounce, below EMA200"
        elif price < ema200 and rsi > 50:
            return f"RSI {rsi:.0f} bounce in downtrend"
        elif rsi >= 50:
            return f"Momentum building, RSI {rsi:.0f}"
        return f"Momentum setup, RSI {rsi:.0f}"

    elif setup == 'Reversal':
        if rsi < 35 and hist > 0:
            return f"Oversold RSI {rsi:.0f}, MACD turning up"
        elif rsi < 35:
            return f"Oversold RSI {rsi:.0f}, watch for turn"
        elif hist > 0 and downtrend:
            return f"Downtrend weakening, MACD improving"
        return f"Divergence forming, RSI {rsi:.0f}"

    else:
        if downtrend and adx > 40:
            return f"Strong downtrend ADX {adx:.0f}, wait"
        elif downtrend and adx > 25:
            return f"Downtrend ADX {adx:.0f}, no setup yet"
        elif bounce:
            return f"Bounce in downtrend, below EMA200"
        elif rsi < 25:
            return f"Deeply oversold RSI {rsi:.0f}, too early"
        elif rsi < 40:
            return f"Oversold RSI {rsi:.0f}, watch for turn"
        elif rsi > 60 and not uptrend:
            return f"RSI {rsi:.0f} bounce, below EMA200"
        else:
            return f"RSI {rsi:.0f}, setup not confirmed"


# ── Header ────────────────────────────────────────────────────────────────────
today = datetime.now().strftime('%d %B %Y')
print(f"{'='*78}")
print(f"  AI STOCK SCREENER — WEEKLY REPORT")
print(f"  {today}")
print(f"{'='*78}")
print(f"\n  SecRank = rank vs same sector  |  CapRank = rank vs same sector + same cap")

# ── TIER 1 ────────────────────────────────────────────────────────────────────
tier1 = tech_df[tech_df['Tier'].str.startswith('TIER 1')].copy()
tier1 = tier1.sort_values(['Cap Category', 'Fund Score'], ascending=[True, False])

cap_order = ['Large Cap', 'Mini Large Cap', 'Mid Cap', 'Small Cap']

print(f"\n{'─'*78}")
print(f"  TIER 1 — ACT NOW  ({len(tier1)} stocks)")
print(f"  Fundamentally strong + Technical setup confirmed")
print(f"{'─'*78}")

current_cap = None
for _, row in tier1.iterrows():
    cap = row['Cap Category']
    if cap != current_cap:
        current_cap = cap
        print(f"\n  [{cap[:1]}{'L' if cap == 'Mini Large Cap' else ''}] {cap}")
        print(f"  {'─'*68}")

    consol_line = ''
    if row['In Consolidation'] and row['Consol Days'] > 0:
        consol_line = f"\n    Base    : {row['Consol Days']}d ({row['Consol Label']}) | {row['Pct to Breakout']:+.1f}% to breakout"

    reason    = get_reason(row)
    vol_label = row['Vol Label']
    vol_inf   = row['Vol Inference']
    sec_trend = row['Sector Trend']
    sec_det   = row['Sector Detail']

    print(f"""
    {row['Symbol']}  ({row['Sector']})  MCap Rs{row['Market Cap Cr']:,.0f}Cr
    Setup   : {row['Best Setup']:10}  Tech {row['Tech Score']:3.0f}/100
    Scores  : Fund {row['Fund Score']}/100  Sector Rank {row['Sector Score']}/10  Cap Rank {row['Cap Score']}/10
    Price   : Rs{row['Current Price']:.2f}  RSI {row['RSI']:.0f}  ADX {row['ADX']:.0f}  MACD {row['MACD Hist']:+.2f}{consol_line}
    Tech    : {reason}
    Volume  : {row['Vol Ratio']:.1f}x ({vol_label}) → {vol_inf}
    Sector  : {sec_trend} | {sec_det}""")

# ── TIER 2A ───────────────────────────────────────────────────────────────────
tier2a = tech_df[tech_df['Tier'] == 'TIER 2 — WATCHLIST'].copy()
tier2a = tier2a.sort_values('Fund Score', ascending=False)

print(f"\n{'─'*78}")
print(f"  TIER 2A — WATCHLIST  ({len(tier2a)} stocks)")
print(f"  Setup forming — wait for confirmation before entering")
print(f"{'─'*78}")
print(f"\n  {'Symbol':10} {'Fund':5} {'SecRnk':7} {'CapRnk':7} {'Setup':10} "
      f"{'Tech':4} {'RSI':4} {'ADX':4}  {'Vol':5}")
print(f"  {'Tech Reason'}")
print(f"  {'Vol Inference'}")
print(f"  {'Sector Trend'}")
print(f"  {'─'*76}")

for _, row in tier2a.iterrows():
    consol_tag = f" [{row['Consol Days']}d]" if row['In Consolidation'] else ''
    reason     = get_reason(row)
    vol_label  = row['Vol Label']
    vol_inf    = row['Vol Inference']
    sec_trend  = row['Sector Trend']
    sec_det    = row['Sector Detail']

    print(f"\n  {row['Symbol']:10} {row['Fund Score']:4.1f}  "
          f"{row['Sector Score']:5.1f}/10  {row['Cap Score']:5.1f}/10  "
          f"{row['Best Setup']:10} {row['Tech Score']:3.0f}  "
          f"{row['RSI']:4.0f}  {row['ADX']:4.0f}  "
          f"{row['Vol Ratio']:.1f}x{consol_tag}")
    print(f"    Tech  : {reason}")
    print(f"    Vol   : {vol_label} → {vol_inf}")
    print(f"    Sector: {sec_trend} | {sec_det}")

# ── TIER 2B ───────────────────────────────────────────────────────────────────
tier2b = tech_df[tech_df['Tier'] == 'TIER 2 — BASE BUILDING'].copy()
tier2b = tier2b.sort_values('Fund Score', ascending=False)

print(f"\n{'─'*78}")
print(f"  TIER 2B — BASE BUILDING  ({len(tier2b)} stocks)")
print(f"  Long consolidation base — watch for volume breakout")
print(f"{'─'*78}")
print(f"\n  {'Symbol':10} {'Fund':5} {'SecRnk':7} {'CapRnk':7} "
      f"{'Days':6} {'Range%':7} {'ToBreak':8} {'Vol':5}")
print(f"  {'Tech Reason'}")
print(f"  {'Vol Inference'}")
print(f"  {'Sector Trend'}")
print(f"  {'─'*76}")

for _, row in tier2b.iterrows():
    reason    = get_reason(row)
    vol_label = row['Vol Label']
    vol_inf   = row['Vol Inference']
    sec_trend = row['Sector Trend']
    sec_det   = row['Sector Detail']

    print(f"\n  {row['Symbol']:10} {row['Fund Score']:4.1f}  "
          f"{row['Sector Score']:5.1f}/10  {row['Cap Score']:5.1f}/10  "
          f"{row['Consol Days']:5}d  "
          f"{row.get('Range Pct', 0):6.1f}%  "
          f"{row['Pct to Breakout']:+7.1f}%  "
          f"{row['Consol Volume']:.1f}x")
    print(f"    Tech  : {reason}")
    print(f"    Vol   : {vol_label} → {vol_inf}")
    print(f"    Sector: {sec_trend} | {sec_det}")

# ── TIER 3 ────────────────────────────────────────────────────────────────────
tier3 = tech_df[tech_df['Tier'] == 'TIER 3 — WAITING'].copy()
tier3 = tier3.sort_values('Fund Score', ascending=False)

print(f"\n{'─'*78}")
print(f"  TIER 3 — WAITING  ({len(tier3)} stocks)")
print(f"  Good businesses — technical setup not ready yet")
print(f"{'─'*78}")

current_cap = None
for _, row in tier3.iterrows():
    cap = row['Cap Category']
    if cap != current_cap:
        current_cap = cap
        print(f"\n  [{cap[0]}{'L' if cap == 'Mini Large Cap' else ''}] {cap}")
        print(f"  {'Symbol':10} {'Fund':5} {'SecRnk':7} {'CapRnk':7} "
              f"{'RSI':4} {'ADX':4}  {'Vol':5}")
        print(f"  {'─'*70}")

    consol_tag = f" [{row['Consol Days']}d base]" if row['In Consolidation'] else ''
    reason     = get_reason(row)
    vol_inf    = row['Vol Inference']
    sec_trend  = row['Sector Trend']
    sec_det    = row['Sector Detail']

    print(f"\n  {row['Symbol']:10} {row['Fund Score']:4.1f}  "
          f"{row['Sector Score']:5.1f}/10  {row['Cap Score']:5.1f}/10  "
          f"{row['RSI']:4.0f}  {row['ADX']:4.0f}  "
          f"{row['Vol Ratio']:.1f}x{consol_tag}")
    print(f"    Tech  : {reason}")
    print(f"    Vol   : {row['Vol Label']} → {vol_inf}")
    print(f"    Sector: {sec_trend} | {sec_det}")

# ── LONG BASE WATCH ───────────────────────────────────────────────────────────
consol_stocks = tech_df[tech_df['In Consolidation'] == True].copy()
consol_stocks = consol_stocks.sort_values('Consol Days', ascending=False)

print(f"\n{'─'*78}")
print(f"  LONG BASE WATCH  ({len(consol_stocks)} stocks, 300+ days)")
print(f"  Watch for breakout above range high with 2x+ volume")
print(f"{'─'*78}")
print(f"  {'Symbol':12} {'Category':14} {'Fund':5} "
      f"{'SecRnk':7} {'CapRnk':7} "
      f"{'Days':6} {'Range%':7} {'ToBreak':8} {'Vol':5}  Status")
print(f"  {'─'*78}")

for _, row in consol_stocks.iterrows():
    pct = row['Pct to Breakout']
    if   pct > -5:   status = "NEAR BREAKOUT"
    elif pct > -15:  status = "Approaching"
    else:            status = "Early stage"

    range_pct = row.get('Range Pct', 0)

    print(f"  {row['Symbol']:12} "
          f"{row['Cap Category']:14} "
          f"{row['Fund Score']:4.1f}  "
          f"{row['Sector Score']:5.1f}/10  "
          f"{row['Cap Score']:5.1f}/10  "
          f"{row['Consol Days']:5}d  "
          f"{range_pct:6.1f}%  "
          f"{pct:+7.1f}%  "
          f"{row['Consol Volume']:.1f}x  "
          f"{status}")

print(f"\n{'─'*78}")
print(f"  L=Large Cap  ML=Mini Large Cap  M=Mid Cap  S=Small Cap")
print(f"  SecRank = rank vs same sector | CapRank = rank vs same sector + cap")
print(f"{'─'*78}")

# ── Save updated tech_df ──────────────────────────────────────────────────────
tech_df.to_csv('../data/technical_report.csv', index=False)
print("\nSaved: data/technical_report.csv ✅")
# Out:
# ==============================================================================
#   AI STOCK SCREENER — WEEKLY REPORT
#   16 March 2026
# ==============================================================================
#
#   SecRank = rank vs same sector  |  CapRank = rank vs same sector + same cap
#
# ──────────────────────────────────────────────────────────────────────────────
#   TIER 1 — ACT NOW  (4 stocks)
#   Fundamentally strong + Technical setup confirmed
# ──────────────────────────────────────────────────────────────────────────────
#
#   [L] Large Cap
#   ────────────────────────────────────────────────────────────────────
#
#     SUNPHARMA  (Healthcare)  MCap Rs432,264Cr
#     Setup   : Momentum    Tech 100/100
#     Scores  : Fund 65.0/100  Sector Rank 10.0/10  Cap Rank 10.0/10
#     Price   : Rs1801.60  RSI 61  ADX 40  MACD +5.11
#     Base    : 520d (520d (1.5-2 years)) | -2.7% to breakout
#     Tech    : Uptrend confirmed, RSI 61, ADX 40
#     Volume  : 1.1x (Normal) → Average volume → monitor for increase
#     Sector  : Weak Uptrend → | RSI 37.4 | ADX 22.1 | Above EMA200
#
#   [ML] Mini Large Cap
#   ────────────────────────────────────────────────────────────────────
#
#     PERSISTENT  (Information Technology)  MCap Rs72,535Cr
#     Setup   : Reversal    Tech 100/100
#     Scores  : Fund 80.0/100  Sector Rank 10.0/10  Cap Rank 10.0/10
#     Price   : Rs4638.80  RSI 28  ADX 57  MACD +23.73
#     Base    : 383d (383d (1-1.5 years)) | -28.1% to breakout
#     Tech    : Oversold RSI 28, MACD turning up
#     Volume  : 0.5x (Very Low) → Sellers exhausted → reversal likely
#     Sector  : Downtrend ↓ | RSI 10.3 | ADX 65.3 | Below EMA200
#
#     ABSLAMC  (Financial Services)  MCap Rs26,938Cr
#     Setup   : Momentum    Tech  95/100
#     Scores  : Fund 67.0/100  Sector Rank 9.1/10  Cap Rank 10.0/10
#     Price   : Rs932.80  RSI 51  ADX 35  MACD +4.46
#     Tech    : Uptrend confirmed, RSI 51, ADX 35
#     Volume  : 0.4x (Very Low) → Very low volume → no conviction, caution
#     Sector  : Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#     LTTS  (Information Technology)  MCap Rs36,358Cr
#     Setup   : Reversal    Tech  65/100
#     Scores  : Fund 61.0/100  Sector Rank 7.6/10  Cap Rank 7.6/10
#     Price   : Rs3430.10  RSI 60  ADX 44  MACD +18.02
#     Tech    : Downtrend weakening, MACD improving
#     Volume  : 10.8x (Very High) → High volume → could be capitulation or distribution
#     Sector  : Downtrend ↓ | RSI 10.3 | ADX 65.3 | Below EMA200
#
# ──────────────────────────────────────────────────────────────────────────────
#   TIER 2A — WATCHLIST  (3 stocks)
#   Setup forming — wait for confirmation before entering
# ──────────────────────────────────────────────────────────────────────────────
#
#   Symbol     Fund  SecRnk  CapRnk  Setup      Tech RSI  ADX   Vol
#   Tech Reason
#   Vol Inference
#   Sector Trend
#   ────────────────────────────────────────────────────────────────────────────
#
#   FINEORG    73.0   10.0/10   10.0/10  Reversal    55    39    32  0.4x [798d]
#     Tech  : Divergence forming, RSI 39
#     Vol   : Very Low → Sellers exhausted → reversal likely
#     Sector: Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   HAPPSTMNDS 64.8    8.1/10   10.0/10  Momentum    55    60    38  0.7x
#     Tech  : RSI 60 bounce in downtrend
#     Vol   : Low → Weak volume → momentum may fade, wait
#     Sector: Downtrend ↓ | RSI 10.3 | ADX 65.3 | Below EMA200
#
#   GARFIBRES  64.0   10.0/10   10.0/10  Reversal    50    28    27  3.6x
#     Tech  : Oversold RSI 28, watch for turn
#     Vol   : Very High → High volume → could be capitulation or distribution
#     Sector: Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
# ──────────────────────────────────────────────────────────────────────────────
#   TIER 2B — BASE BUILDING  (2 stocks)
#   Long consolidation base — watch for volume breakout
# ──────────────────────────────────────────────────────────────────────────────
#
#   Symbol     Fund  SecRnk  CapRnk  Days   Range%  ToBreak  Vol
#   Tech Reason
#   Vol Inference
#   Sector Trend
#   ────────────────────────────────────────────────────────────────────────────
#
#   HAL        62.0    9.1/10    9.1/10    484d     0.0%    -23.9%  1.1x
#     Tech  : Downtrend ADX 27, no setup yet
#     Vol   : Normal → Low activity → no setup forming yet
#     Sector: Downtrend ↓ | RSI 21.6 | ADX 42.2 | Below EMA200
#
#   GRANULES   60.0    9.2/10   10.0/10    440d     0.0%    -15.7%  1.1x
#     Tech  : RSI 40, setup not confirmed
#     Vol   : Low → Low activity → no setup forming yet
#     Sector: Weak Uptrend → | RSI 37.4 | ADX 22.1 | Above EMA200
#
# ──────────────────────────────────────────────────────────────────────────────
#   TIER 3 — WAITING  (26 stocks)
#   Good businesses — technical setup not ready yet
# ──────────────────────────────────────────────────────────────────────────────
#
#   [L] Large Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   MUTHOOTFIN 73.4   10.0/10   10.0/10    48    40  1.2x
#     Tech  : Strong downtrend ADX 40, wait
#     Vol   : Normal → Strong downtrend → no entry signal
#     Sector: Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   CHOLAFIN   70.7    9.6/10    9.6/10    24    52  0.8x
#     Tech  : Strong downtrend ADX 52, wait
#     Vol   : Low → Strong downtrend → no entry signal
#     Sector: Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   [S] Small Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   DHANUKA    69.0    9.5/10   10.0/10    35    38  0.8x
#     Tech  : Downtrend ADX 38, no setup yet
#     Vol   : Low → Low activity → no setup forming yet
#     Sector: Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   [L] Large Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   TITAN      69.0   10.0/10   10.0/10    31    36  1.4x
#     Tech  : Downtrend ADX 36, no setup yet
#     Vol   : Normal → Low activity → no setup forming yet
#     Sector: Downtrend ↓ | RSI 28.0 | ADX 49.1 | Below EMA200
#
#   BEL        68.0   10.0/10   10.0/10    40    29  1.1x
#     Tech  : Downtrend ADX 29, no setup yet
#     Vol   : Normal → Low activity → no setup forming yet
#     Sector: Downtrend ↓ | RSI 21.6 | ADX 42.2 | Below EMA200
#
#   [ML] Mini Large Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   PIIND      68.0    9.3/10   10.0/10    25    23  1.1x
#     Tech  : Deeply oversold RSI 25, too early
#     Vol   : Normal → Low activity → no setup forming yet
#     Sector: Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   [L] Large Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   DIVISLAB   64.0    9.8/10    9.8/10    26    28  0.8x
#     Tech  : Downtrend ADX 28, no setup yet
#     Vol   : Low → Low activity → no setup forming yet
#     Sector: Weak Uptrend → | RSI 37.4 | ADX 22.1 | Above EMA200
#
#   TCS        64.0    8.0/10   10.0/10    11    55  0.6x
#     Tech  : Strong downtrend ADX 55, wait
#     Vol   : Very Low → Strong downtrend → no entry signal
#     Sector: Downtrend ↓ | RSI 10.3 | ADX 65.3 | Below EMA200
#
#   [M] Mid Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   PARAS      63.2    9.3/10   10.0/10    35    35  0.3x
#     Tech  : Downtrend ADX 35, no setup yet
#     Vol   : Very Low → Very low volume → no interest, wait
#     Sector: Downtrend ↓ | RSI 21.6 | ADX 42.2 | Below EMA200
#
#   AAVAS      60.8    8.3/10   10.0/10    20    55  0.6x
#     Tech  : Strong downtrend ADX 55, wait
#     Vol   : Very Low → Strong downtrend → no entry signal
#     Sector: Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   [ML] Mini Large Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   HAVELLS    59.0    8.6/10   10.0/10    32    23  2.3x
#     Tech  : Oversold RSI 32, watch for turn
#     Vol   : Very High → High volume → could be capitulation or distribution
#     Sector: Downtrend ↓ | RSI 28.0 | ADX 49.1 | Below EMA200
#
#   [M] Mid Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   VINATIORGA 58.0    7.9/10    7.9/10    25    43  1.6x
#     Tech  : Oversold RSI 25, watch for turn
#     Vol   : High → High volume → could be capitulation or distribution
#     Sector: Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   [L] Large Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   RELIANCE   55.0   10.0/10   10.0/10    41    28  1.1x [606d base]
#     Tech  : Downtrend ADX 28, no setup yet
#     Vol   : Normal → Low activity → no setup forming yet
#     Sector: Weak Uptrend → | RSI 40.8 | ADX 19.8 | Above EMA200
#
#   [ML] Mini Large Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   IPCALAB    53.0    8.2/10   10.0/10    70    22  2.9x [481d base]
#     Tech  : Momentum building, RSI 70
#     Vol   : Very High → Strong participation → trend likely to continue
#     Sector: Weak Uptrend → | RSI 37.4 | ADX 22.1 | Above EMA200
#
#   [S] Small Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   WONDERLA   51.0   10.0/10   10.0/10    65    33  1.1x
#     Tech  : Short bounce, below EMA200
#     Vol   : Normal → Average volume → monitor for increase
#     Sector: Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   [M] Mid Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   GALAXYSURF 50.0    6.8/10    6.8/10    23    29  1.3x
#     Tech  : Downtrend ADX 29, no setup yet
#     Vol   : Normal → Low activity → no setup forming yet
#     Sector: Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   VGUARD     49.0    7.1/10   10.0/10    57    24  1.9x
#     Tech  : RSI 57, setup not confirmed
#     Vol   : High → Above avg volume but no setup → watch
#     Sector: Downtrend ↓ | RSI 28.0 | ADX 49.1 | Below EMA200
#
#   [L] Large Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   WIPRO      49.0    6.1/10    7.7/10    33    41  0.7x
#     Tech  : Oversold RSI 33, MACD turning up
#     Vol   : Very Low → Low volume on down move → selling pressure easing
#     Sector: Downtrend ↓ | RSI 10.3 | ADX 65.3 | Below EMA200
#
#   [M] Mid Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   SYMPHONY   48.7    7.1/10    9.9/10    46    38  0.7x
#     Tech  : Downtrend ADX 38, no setup yet
#     Vol   : Low → Low activity → no setup forming yet
#     Sector: Downtrend ↓ | RSI 28.0 | ADX 49.1 | Below EMA200
#
#   SUPRAJIT   45.0   10.0/10   10.0/10    31    25  0.8x [491d base]
#     Tech  : Oversold RSI 31, watch for turn
#     Vol   : Low → Neutral volume → wait for low-volume base to form
#     Sector: Downtrend ↓ | RSI 28.7 | ADX 41.4 | Below EMA200
#
#   CREDITACC  41.4    5.6/10    6.8/10    34    19  0.7x
#     Tech  : Oversold RSI 34, watch for turn
#     Vol   : Low → Neutral volume → wait for low-volume base to form
#     Sector: Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   [S] Small Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   HIMATSEIDE 40.0    6.2/10   10.0/10    14    44  1.4x
#     Tech  : Strong downtrend ADX 44, wait
#     Vol   : Normal → Strong downtrend → no entry signal
#     Sector: Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   [M] Mid Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   APLLTD     39.0    6.0/10    6.5/10    17    42  0.8x
#     Tech  : Oversold RSI 17, watch for turn
#     Vol   : Low → Neutral volume → wait for low-volume base to form
#     Sector: Weak Uptrend → | RSI 37.4 | ADX 22.1 | Above EMA200
#
#   MIDHANI    35.0    5.1/10    5.5/10    26    17  1.2x
#     Tech  : Oversold RSI 26, watch for turn
#     Vol   : Normal → Low activity → no setup forming yet
#     Sector: Downtrend ↓ | RSI 21.6 | ADX 42.2 | Below EMA200
#
#   MANAPPURAM 31.9    4.3/10    5.2/10    21    46  0.6x
#     Tech  : Strong downtrend ADX 46, wait
#     Vol   : Very Low → Strong downtrend → no entry signal
#     Sector: Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   [S] Small Cap
#   Symbol     Fund  SecRnk  CapRnk  RSI  ADX   Vol
#   ──────────────────────────────────────────────────────────────────────
#
#   RALLIS     30.0    4.1/10    4.3/10    21    28  0.5x
#     Tech  : Downtrend ADX 28, no setup yet
#     Vol   : Very Low → Very low volume → no interest, wait
#     Sector: Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
# ──────────────────────────────────────────────────────────────────────────────
#   LONG BASE WATCH  (8 stocks, 300+ days)
#   Watch for breakout above range high with 2x+ volume
# ──────────────────────────────────────────────────────────────────────────────
#   Symbol       Category       Fund  SecRnk  CapRnk  Days   Range%  ToBreak  Vol    Status
#   ──────────────────────────────────────────────────────────────────────────────
#   FINEORG      Mid Cap        73.0   10.0/10   10.0/10    798d     0.0%    -21.6%  0.6x  Early stage
#   RELIANCE     Large Cap      55.0   10.0/10   10.0/10    606d     0.0%    -11.5%  1.8x  Approaching
#   SUNPHARMA    Large Cap      65.0   10.0/10   10.0/10    520d     0.0%     -2.7%  1.8x  NEAR BREAKOUT
#   SUPRAJIT     Mid Cap        45.0   10.0/10   10.0/10    491d     0.0%    -24.2%  0.9x  Early stage
#   HAL          Large Cap      62.0    9.1/10    9.1/10    484d     0.0%    -23.9%  1.1x  Early stage
#   IPCALAB      Mini Large Cap 53.0    8.2/10   10.0/10    481d     0.0%     -3.2%  2.9x  NEAR BREAKOUT
#   GRANULES     Mid Cap        60.0    9.2/10   10.0/10    440d     0.0%    -15.7%  1.1x  Early stage
#   PERSISTENT   Mini Large Cap 80.0   10.0/10   10.0/10    383d     0.0%    -28.1%  0.8x  Early stage
#
# ──────────────────────────────────────────────────────────────────────────────
#   L=Large Cap  ML=Mini Large Cap  M=Mid Cap  S=Small Cap
#   SecRank = rank vs same sector | CapRank = rank vs same sector + cap
# ──────────────────────────────────────────────────────────────────────────────
#
# Saved: data/technical_report.csv ✅

# %%
# Check 1: Range Pct column
print("Columns in tech_df:", [c for c in tech_df.columns if 'Range' in c or 'Consol' in c])

# Check 2: Cap category sort order
print("\nTier 3 cap categories:")
tier3_check = tech_df[tech_df['Tier'] == 'TIER 3 — WAITING'].copy()
print(tier3_check[['Symbol', 'Cap Category', 'Fund Score']].sort_values(
    ['Cap Category', 'Fund Score'], ascending=[True, False]).to_string())
# Out:
# Columns in tech_df: ['In Consolidation', 'Consol Days', 'Consol Label', 'Consol Volume']
#
# Tier 3 cap categories:
#         Symbol    Cap Category  Fund Score
# 7   MUTHOOTFIN       Large Cap        73.4
# 6     CHOLAFIN       Large Cap        70.7
# 26       TITAN       Large Cap        69.0
# 14         BEL       Large Cap        68.0
# 0          TCS       Large Cap        64.0
# 22    DIVISLAB       Large Cap        64.0
# 1     RELIANCE       Large Cap        55.0
# 2        WIPRO       Large Cap        49.0
# 16       PARAS         Mid Cap        63.2
# 20       AAVAS         Mid Cap        60.8
# 17  VINATIORGA         Mid Cap        58.0
# 19  GALAXYSURF         Mid Cap        50.0
# 28      VGUARD         Mid Cap        49.0
# 29    SYMPHONY         Mid Cap        48.7
# 11    SUPRAJIT         Mid Cap        45.0
# 9    CREDITACC         Mid Cap        41.4
# 23      APLLTD         Mid Cap        39.0
# 15     MIDHANI         Mid Cap        35.0
# 8   MANAPPURAM         Mid Cap        31.9
# 31       PIIND  Mini Large Cap        68.0
# 27     HAVELLS  Mini Large Cap        59.0
# 25     IPCALAB  Mini Large Cap        53.0
# 33     DHANUKA       Small Cap        69.0
# 30    WONDERLA       Small Cap        51.0
# 12  HIMATSEIDE       Small Cap        40.0
# 32      RALLIS       Small Cap        30.0

# %%
# Fix 1: Load Range Pct from consolidation_info.csv
consol_info_df = pd.read_csv('../data/consolidation_info.csv')
print("Consolidation info columns:", consol_info_df.columns.tolist())
print(consol_info_df[['Symbol'] + [c for c in consol_info_df.columns if 'range' in c.lower() or 'Range' in c]].head(10))
# Out:
# Consolidation info columns: ['Symbol', 'Fund Score', 'Sector', 'consol_days', 'duration_label', 'range_pct', 'range_high', 'range_low', 'pct_to_breakout', 'is_breaking_out', 'breakout_volume', 'has_bell', 'current_price']
#        Symbol  range_pct  range_high  range_low
# 0     FINEORG      37.43     5468.25    3978.82
# 1    RELIANCE      34.85     1559.75    1156.63
# 2   SUNPHARMA      26.06     1851.62    1468.86
# 3    SUPRAJIT      38.99      532.59     383.17
# 4         HAL      49.79     5142.18    3432.95
# 5     IPCALAB      37.83     1613.74    1170.79
# 6    GRANULES      47.87      667.07     451.11
# 7  PERSISTENT      36.38     6453.55    4732.07

# %%
# ══════════════════════════════════════════════════════════════════════════════
# COMPLETE WEEKLY REPORT — CLEAN FORMAT
# ══════════════════════════════════════════════════════════════════════════════
from datetime import datetime

today = datetime.now().strftime('%d %B %Y')
print(f"{'='*78}")
print(f"  AI STOCK SCREENER — WEEKLY REPORT")
print(f"  {today}")
print(f"{'='*78}")
print(f"\n  SecRank = rank vs same sector  |  CapRank = rank vs same sector + same cap")

# ── TIER 1 — detailed card (unchanged) ────────────────────────────────────────
tier1 = tech_df[tech_df['Tier'].str.startswith('TIER 1')].copy()
tier1['_cap_order'] = tier1['Cap Category'].apply(lambda x: CAP_ORDER.index(x) if x in CAP_ORDER else 99)
tier1 = tier1.sort_values(['_cap_order', 'Fund Score'], ascending=[True, False]).reset_index(drop=True)

print(f"\n{'─'*78}")
print(f"  TIER 1 — ACT NOW  ({len(tier1)} stocks)")
print(f"  Fundamentally strong + Technical setup confirmed")
print(f"{'─'*78}")

serial = 1
current_cap = None
for _, row in tier1.iterrows():
    cap = row['Cap Category']
    if cap != current_cap:
        current_cap = cap
        cap_short = {'Large Cap':'L','Mini Large Cap':'ML','Mid Cap':'M','Small Cap':'S'}[cap]
        print(f"\n  [{cap_short}] {cap}")
        print(f"  {'─'*68}")

    consol_line = ''
    if row['In Consolidation'] and row['Consol Days'] > 0:
        consol_line = (f"\n    Base    : {row['Consol Days']}d "
                      f"({row['Consol Label']}) | "
                      f"{row['Pct to Breakout']:+.1f}% to breakout")

    print(f"""
  #{serial}  {row['Symbol']}  ({row['Sector']})  MCap Rs{row['Market Cap Cr']:,.0f}Cr
    Setup   : {row['Best Setup']:10}  Tech {row['Tech Score']:3.0f}/100
    Scores  : Fund {row['Fund Score']}/100  Sector Rank {row['Sector Score']}/10  Cap Rank {row['Cap Score']}/10
    Price   : Rs{row['Current Price']:.2f}  RSI {row['RSI']:.0f}  ADX {row['ADX']:.0f}  MACD {row['MACD Hist']:+.2f}{consol_line}
    Tech    : {get_reason(row)}
    Volume  : {row['Vol Ratio']:.1f}x ({row['Vol Label']}) → {row['Vol Inference']}
    Sector  : {row['Sector Trend']} | {row['Sector Detail']}""")
    serial += 1

# ── TIER 2A ────────────────────────────────────────────────────────────────────
tier2a = tech_df[tech_df['Tier'] == 'TIER 2 — WATCHLIST'].copy()
tier2a = tier2a.sort_values('Fund Score', ascending=False).reset_index(drop=True)

print(f"\n{'─'*78}")
print(f"  TIER 2A — WATCHLIST  ({len(tier2a)} stocks)")
print(f"  Setup forming — wait for confirmation before entering")
print(f"{'─'*78}")

for _, row in tier2a.iterrows():
    consol_tag = f"  [{row['Consol Days']}d base]" if row['In Consolidation'] else ''
    # Line 1: identity only
    print(f"\n  #{serial}  {row['Symbol']:10}  "
          f"Fund:{row['Fund Score']:4.1f}  "
          f"Sec:{row['Sector Score']:4.1f}  "
          f"Cap:{row['Cap Score']:4.1f}{consol_tag}")
    # Line 2: Technical — includes RSI, ADX, Setup, Tech score + reason
    print(f"      Technical : Setup:{row['Best Setup']:10}  Tech:{row['Tech Score']:3.0f}  "
          f"RSI:{row['RSI']:4.0f}  ADX:{row['ADX']:4.0f}  → {get_reason(row)}")
    # Line 3: Volume
    print(f"      Volume    : {row['Vol Ratio']:.1f}x {row['Vol Label']} → {row['Vol Inference']}")
    # Line 4: Sector
    print(f"      Sector    : {row['Sector Trend']} | {row['Sector Detail']}")
    serial += 1

# ── TIER 2B ────────────────────────────────────────────────────────────────────
tier2b = tech_df[tech_df['Tier'] == 'TIER 2 — BASE BUILDING'].copy()
tier2b = tier2b.sort_values('Fund Score', ascending=False).reset_index(drop=True)

print(f"\n{'─'*78}")
print(f"  TIER 2B — BASE BUILDING  ({len(tier2b)} stocks)")
print(f"  Long consolidation base — watch for volume breakout")
print(f"{'─'*78}")

for _, row in tier2b.iterrows():
    # Line 1: identity + consolidation info only
    print(f"\n  #{serial}  {row['Symbol']:10}  "
          f"Fund:{row['Fund Score']:4.1f}  "
          f"Sec:{row['Sector Score']:4.1f}  "
          f"Cap:{row['Cap Score']:4.1f}  "
          f"{row['Consol Days']}d  "
          f"Range:{row['range_pct']:.1f}%  "
          f"ToBreak:{row['Pct to Breakout']:+.1f}%")
    # Line 2: Technical — RSI, ADX + reason
    print(f"      Technical : RSI:{row['RSI']:4.0f}  ADX:{row['ADX']:4.0f}  → {get_reason(row)}")
    # Line 3: Volume — both daily vol ratio AND consolidation breakout volume
    print(f"      Volume    : Daily:{row['Vol Ratio']:.1f}x {row['Vol Label']} → {row['Vol Inference']}  |  Breakout vol:{row['Consol Volume']:.1f}x")
    # Line 4: Sector
    print(f"      Sector    : {row['Sector Trend']} | {row['Sector Detail']}")
    serial += 1

# ── TIER 3 ─────────────────────────────────────────────────────────────────────
tier3 = tech_df[tech_df['Tier'] == 'TIER 3 — WAITING'].copy()
tier3['_cap_order'] = tier3['Cap Category'].apply(lambda x: CAP_ORDER.index(x) if x in CAP_ORDER else 99)
tier3 = tier3.sort_values(['_cap_order', 'Fund Score'], ascending=[True, False]).reset_index(drop=True)

print(f"\n{'─'*78}")
print(f"  TIER 3 — WAITING  ({len(tier3)} stocks)")
print(f"  Good businesses — technical setup not ready yet")
print(f"{'─'*78}")

current_cap = None
for _, row in tier3.iterrows():
    cap = row['Cap Category']
    if cap != current_cap:
        current_cap = cap
        cap_short = {'Large Cap':'L','Mini Large Cap':'ML','Mid Cap':'M','Small Cap':'S'}[cap]
        print(f"\n  [{cap_short}] {cap}")
        print(f"  {'─'*68}")

    consol_tag = f"  [{row['Consol Days']}d base]" if row['In Consolidation'] else ''
    # Line 1: identity + Vol only
    print(f"\n  #{serial}  {row['Symbol']:10}  "
          f"Fund:{row['Fund Score']:4.1f}  "
          f"Sec:{row['Sector Score']:4.1f}  "
          f"Cap:{row['Cap Score']:4.1f}  "
          f"Vol:{row['Vol Ratio']:.1f}x{consol_tag}")
    # Line 2: Technical — RSI, ADX + reason
    print(f"      Technical : RSI:{row['RSI']:4.0f}  ADX:{row['ADX']:4.0f}  → {get_reason(row)}")
    # Line 3: Volume
    print(f"      Volume    : {row['Vol Label']} → {row['Vol Inference']}")
    # Line 4: Sector
    print(f"      Sector    : {row['Sector Trend']} | {row['Sector Detail']}")
    serial += 1

# ── LONG BASE WATCH ────────────────────────────────────────────────────────────
consol_stocks = tech_df[tech_df['In Consolidation'] == True].copy()
consol_stocks = consol_stocks.sort_values('Consol Days', ascending=False)

print(f"\n{'─'*78}")
print(f"  LONG BASE WATCH  ({len(consol_stocks)} stocks, 300+ days)")
print(f"  Watch for breakout above range high with 2x+ volume")
print(f"{'─'*78}")
print(f"  {'Symbol':12} {'Category':14} {'Fund':5} "
      f"{'Sec':6} {'Cap':6} "
      f"{'Days':6} {'Range%':7} {'ToBreak':8} {'Vol':5}  Status")
print(f"  {'─'*85}")

for _, row in consol_stocks.iterrows():
    pct    = row['Pct to Breakout']
    status = "NEAR BREAKOUT" if pct > -5 else "Approaching" if pct > -15 else "Early stage"
    print(f"  {row['Symbol']:12} "
          f"{row['Cap Category']:14} "
          f"{row['Fund Score']:4.1f} "
          f"{row['Sector Score']:5.1f} "
          f"{row['Cap Score']:5.1f} "
          f"{row['Consol Days']:5}d "
          f"{row['range_pct']:6.1f}% "
          f"{pct:+7.1f}% "
          f"{row['Consol Volume']:.1f}x  "
          f"{status}")

print(f"\n{'─'*78}")
print(f"  L=Large Cap  ML=Mini Large Cap  M=Mid Cap  S=Small Cap")
print(f"  SecRank = rank vs same sector | CapRank = rank vs same sector + cap")
print(f"{'─'*78}")

tech_df.to_csv('../data/technical_report.csv', index=False)
print("\nSaved: data/technical_report.csv ✅")
# Out:
# ==============================================================================
#   AI STOCK SCREENER — WEEKLY REPORT
#   16 March 2026
# ==============================================================================
#
#   SecRank = rank vs same sector  |  CapRank = rank vs same sector + same cap
#
# ──────────────────────────────────────────────────────────────────────────────
#   TIER 1 — ACT NOW  (4 stocks)
#   Fundamentally strong + Technical setup confirmed
# ──────────────────────────────────────────────────────────────────────────────
#
#   [L] Large Cap
#   ────────────────────────────────────────────────────────────────────
#
#   #1  SUNPHARMA  (Healthcare)  MCap Rs432,264Cr
#     Setup   : Momentum    Tech 100/100
#     Scores  : Fund 65.0/100  Sector Rank 10.0/10  Cap Rank 10.0/10
#     Price   : Rs1801.60  RSI 61  ADX 40  MACD +5.11
#     Base    : 520d (520d (1.5-2 years)) | -2.7% to breakout
#     Tech    : Uptrend confirmed, RSI 61, ADX 40
#     Volume  : 1.1x (Normal) → Average volume → monitor for increase
#     Sector  : Weak Uptrend → | RSI 37.4 | ADX 22.1 | Above EMA200
#
#   [ML] Mini Large Cap
#   ────────────────────────────────────────────────────────────────────
#
#   #2  PERSISTENT  (Information Technology)  MCap Rs72,535Cr
#     Setup   : Reversal    Tech 100/100
#     Scores  : Fund 80.0/100  Sector Rank 10.0/10  Cap Rank 10.0/10
#     Price   : Rs4638.80  RSI 28  ADX 57  MACD +23.73
#     Base    : 383d (383d (1-1.5 years)) | -28.1% to breakout
#     Tech    : Oversold RSI 28, MACD turning up
#     Volume  : 0.5x (Very Low) → Sellers exhausted → reversal likely
#     Sector  : Downtrend ↓ | RSI 10.3 | ADX 65.3 | Below EMA200
#
#   #3  ABSLAMC  (Financial Services)  MCap Rs26,938Cr
#     Setup   : Momentum    Tech  95/100
#     Scores  : Fund 67.0/100  Sector Rank 9.1/10  Cap Rank 10.0/10
#     Price   : Rs932.80  RSI 51  ADX 35  MACD +4.46
#     Tech    : Uptrend confirmed, RSI 51, ADX 35
#     Volume  : 0.4x (Very Low) → Very low volume → no conviction, caution
#     Sector  : Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   #4  LTTS  (Information Technology)  MCap Rs36,358Cr
#     Setup   : Reversal    Tech  65/100
#     Scores  : Fund 61.0/100  Sector Rank 7.6/10  Cap Rank 7.6/10
#     Price   : Rs3430.10  RSI 60  ADX 44  MACD +18.02
#     Tech    : Downtrend weakening, MACD improving
#     Volume  : 10.8x (Very High) → High volume → could be capitulation or distribution
#     Sector  : Downtrend ↓ | RSI 10.3 | ADX 65.3 | Below EMA200
#
# ──────────────────────────────────────────────────────────────────────────────
#   TIER 2A — WATCHLIST  (3 stocks)
#   Setup forming — wait for confirmation before entering
# ──────────────────────────────────────────────────────────────────────────────
#
#   #5  FINEORG     Fund:73.0  Sec:10.0  Cap:10.0  [798d base]
#       Technical : Setup:Reversal    Tech: 55  RSI:  39  ADX:  32  → Divergence forming, RSI 39
#       Volume    : 0.4x Very Low → Sellers exhausted → reversal likely
#       Sector    : Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   #6  HAPPSTMNDS  Fund:64.8  Sec: 8.1  Cap:10.0
#       Technical : Setup:Momentum    Tech: 55  RSI:  60  ADX:  38  → RSI 60 bounce in downtrend
#       Volume    : 0.7x Low → Weak volume → momentum may fade, wait
#       Sector    : Downtrend ↓ | RSI 10.3 | ADX 65.3 | Below EMA200
#
#   #7  GARFIBRES   Fund:64.0  Sec:10.0  Cap:10.0
#       Technical : Setup:Reversal    Tech: 50  RSI:  28  ADX:  27  → Oversold RSI 28, watch for turn
#       Volume    : 3.6x Very High → High volume → could be capitulation or distribution
#       Sector    : Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
# ──────────────────────────────────────────────────────────────────────────────
#   TIER 2B — BASE BUILDING  (2 stocks)
#   Long consolidation base — watch for volume breakout
# ──────────────────────────────────────────────────────────────────────────────
#
#   #8  HAL         Fund:62.0  Sec: 9.1  Cap: 9.1  484d  Range:49.8%  ToBreak:-23.9%
#       Technical : RSI:  38  ADX:  27  → Downtrend ADX 27, no setup yet
#       Volume    : Daily:1.1x Normal → Low activity → no setup forming yet  |  Breakout vol:1.1x
#       Sector    : Downtrend ↓ | RSI 21.6 | ADX 42.2 | Below EMA200
#
#   #9  GRANULES    Fund:60.0  Sec: 9.2  Cap:10.0  440d  Range:47.9%  ToBreak:-15.7%
#       Technical : RSI:  40  ADX:  18  → RSI 40, setup not confirmed
#       Volume    : Daily:0.7x Low → Low activity → no setup forming yet  |  Breakout vol:1.1x
#       Sector    : Weak Uptrend → | RSI 37.4 | ADX 22.1 | Above EMA200
#
# ──────────────────────────────────────────────────────────────────────────────
#   TIER 3 — WAITING  (26 stocks)
#   Good businesses — technical setup not ready yet
# ──────────────────────────────────────────────────────────────────────────────
#
#   [L] Large Cap
#   ────────────────────────────────────────────────────────────────────
#
#   #10  MUTHOOTFIN  Fund:73.4  Sec:10.0  Cap:10.0  Vol:1.2x
#       Technical : RSI:  48  ADX:  40  → Strong downtrend ADX 40, wait
#       Volume    : Normal → Strong downtrend → no entry signal
#       Sector    : Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   #11  CHOLAFIN    Fund:70.7  Sec: 9.6  Cap: 9.6  Vol:0.8x
#       Technical : RSI:  24  ADX:  52  → Strong downtrend ADX 52, wait
#       Volume    : Low → Strong downtrend → no entry signal
#       Sector    : Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   #12  TITAN       Fund:69.0  Sec:10.0  Cap:10.0  Vol:1.4x
#       Technical : RSI:  31  ADX:  36  → Downtrend ADX 36, no setup yet
#       Volume    : Normal → Low activity → no setup forming yet
#       Sector    : Downtrend ↓ | RSI 28.0 | ADX 49.1 | Below EMA200
#
#   #13  BEL         Fund:68.0  Sec:10.0  Cap:10.0  Vol:1.1x
#       Technical : RSI:  40  ADX:  29  → Downtrend ADX 29, no setup yet
#       Volume    : Normal → Low activity → no setup forming yet
#       Sector    : Downtrend ↓ | RSI 21.6 | ADX 42.2 | Below EMA200
#
#   #14  TCS         Fund:64.0  Sec: 8.0  Cap:10.0  Vol:0.6x
#       Technical : RSI:  11  ADX:  55  → Strong downtrend ADX 55, wait
#       Volume    : Very Low → Strong downtrend → no entry signal
#       Sector    : Downtrend ↓ | RSI 10.3 | ADX 65.3 | Below EMA200
#
#   #15  DIVISLAB    Fund:64.0  Sec: 9.8  Cap: 9.8  Vol:0.8x
#       Technical : RSI:  26  ADX:  28  → Downtrend ADX 28, no setup yet
#       Volume    : Low → Low activity → no setup forming yet
#       Sector    : Weak Uptrend → | RSI 37.4 | ADX 22.1 | Above EMA200
#
#   #16  RELIANCE    Fund:55.0  Sec:10.0  Cap:10.0  Vol:1.1x  [606d base]
#       Technical : RSI:  41  ADX:  28  → Downtrend ADX 28, no setup yet
#       Volume    : Normal → Low activity → no setup forming yet
#       Sector    : Weak Uptrend → | RSI 40.8 | ADX 19.8 | Above EMA200
#
#   #17  WIPRO       Fund:49.0  Sec: 6.1  Cap: 7.7  Vol:0.7x
#       Technical : RSI:  33  ADX:  41  → Oversold RSI 33, MACD turning up
#       Volume    : Very Low → Low volume on down move → selling pressure easing
#       Sector    : Downtrend ↓ | RSI 10.3 | ADX 65.3 | Below EMA200
#
#   [ML] Mini Large Cap
#   ────────────────────────────────────────────────────────────────────
#
#   #18  PIIND       Fund:68.0  Sec: 9.3  Cap:10.0  Vol:1.1x
#       Technical : RSI:  25  ADX:  23  → Deeply oversold RSI 25, too early
#       Volume    : Normal → Low activity → no setup forming yet
#       Sector    : Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   #19  HAVELLS     Fund:59.0  Sec: 8.6  Cap:10.0  Vol:2.3x
#       Technical : RSI:  32  ADX:  23  → Oversold RSI 32, watch for turn
#       Volume    : Very High → High volume → could be capitulation or distribution
#       Sector    : Downtrend ↓ | RSI 28.0 | ADX 49.1 | Below EMA200
#
#   #20  IPCALAB     Fund:53.0  Sec: 8.2  Cap:10.0  Vol:2.9x  [481d base]
#       Technical : RSI:  70  ADX:  22  → Momentum building, RSI 70
#       Volume    : Very High → Strong participation → trend likely to continue
#       Sector    : Weak Uptrend → | RSI 37.4 | ADX 22.1 | Above EMA200
#
#   [M] Mid Cap
#   ────────────────────────────────────────────────────────────────────
#
#   #21  PARAS       Fund:63.2  Sec: 9.3  Cap:10.0  Vol:0.3x
#       Technical : RSI:  35  ADX:  35  → Downtrend ADX 35, no setup yet
#       Volume    : Very Low → Very low volume → no interest, wait
#       Sector    : Downtrend ↓ | RSI 21.6 | ADX 42.2 | Below EMA200
#
#   #22  AAVAS       Fund:60.8  Sec: 8.3  Cap:10.0  Vol:0.6x
#       Technical : RSI:  20  ADX:  55  → Strong downtrend ADX 55, wait
#       Volume    : Very Low → Strong downtrend → no entry signal
#       Sector    : Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   #23  VINATIORGA  Fund:58.0  Sec: 7.9  Cap: 7.9  Vol:1.6x
#       Technical : RSI:  25  ADX:  43  → Oversold RSI 25, watch for turn
#       Volume    : High → High volume → could be capitulation or distribution
#       Sector    : Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   #24  GALAXYSURF  Fund:50.0  Sec: 6.8  Cap: 6.8  Vol:1.3x
#       Technical : RSI:  23  ADX:  29  → Downtrend ADX 29, no setup yet
#       Volume    : Normal → Low activity → no setup forming yet
#       Sector    : Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   #25  VGUARD      Fund:49.0  Sec: 7.1  Cap:10.0  Vol:1.9x
#       Technical : RSI:  57  ADX:  24  → RSI 57, setup not confirmed
#       Volume    : High → Above avg volume but no setup → watch
#       Sector    : Downtrend ↓ | RSI 28.0 | ADX 49.1 | Below EMA200
#
#   #26  SYMPHONY    Fund:48.7  Sec: 7.1  Cap: 9.9  Vol:0.7x
#       Technical : RSI:  46  ADX:  38  → Downtrend ADX 38, no setup yet
#       Volume    : Low → Low activity → no setup forming yet
#       Sector    : Downtrend ↓ | RSI 28.0 | ADX 49.1 | Below EMA200
#
#   #27  SUPRAJIT    Fund:45.0  Sec:10.0  Cap:10.0  Vol:0.8x  [491d base]
#       Technical : RSI:  31  ADX:  25  → Oversold RSI 31, watch for turn
#       Volume    : Low → Neutral volume → wait for low-volume base to form
#       Sector    : Downtrend ↓ | RSI 28.7 | ADX 41.4 | Below EMA200
#
#   #28  CREDITACC   Fund:41.4  Sec: 5.6  Cap: 6.8  Vol:0.7x
#       Technical : RSI:  34  ADX:  19  → Oversold RSI 34, watch for turn
#       Volume    : Low → Neutral volume → wait for low-volume base to form
#       Sector    : Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   #29  APLLTD      Fund:39.0  Sec: 6.0  Cap: 6.5  Vol:0.8x
#       Technical : RSI:  17  ADX:  42  → Oversold RSI 17, watch for turn
#       Volume    : Low → Neutral volume → wait for low-volume base to form
#       Sector    : Weak Uptrend → | RSI 37.4 | ADX 22.1 | Above EMA200
#
#   #30  MIDHANI     Fund:35.0  Sec: 5.1  Cap: 5.5  Vol:1.2x
#       Technical : RSI:  26  ADX:  17  → Oversold RSI 26, watch for turn
#       Volume    : Normal → Low activity → no setup forming yet
#       Sector    : Downtrend ↓ | RSI 21.6 | ADX 42.2 | Below EMA200
#
#   #31  MANAPPURAM  Fund:31.9  Sec: 4.3  Cap: 5.2  Vol:0.6x
#       Technical : RSI:  21  ADX:  46  → Strong downtrend ADX 46, wait
#       Volume    : Very Low → Strong downtrend → no entry signal
#       Sector    : Downtrend ↓ | RSI 35.7 | ADX 32.0 | Below EMA200
#
#   [S] Small Cap
#   ────────────────────────────────────────────────────────────────────
#
#   #32  DHANUKA     Fund:69.0  Sec: 9.5  Cap:10.0  Vol:0.8x
#       Technical : RSI:  35  ADX:  38  → Downtrend ADX 38, no setup yet
#       Volume    : Low → Low activity → no setup forming yet
#       Sector    : Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   #33  WONDERLA    Fund:51.0  Sec:10.0  Cap:10.0  Vol:1.1x
#       Technical : RSI:  65  ADX:  33  → Short bounce, below EMA200
#       Volume    : Normal → Average volume → monitor for increase
#       Sector    : Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   #34  HIMATSEIDE  Fund:40.0  Sec: 6.2  Cap:10.0  Vol:1.4x
#       Technical : RSI:  14  ADX:  44  → Strong downtrend ADX 44, wait
#       Volume    : Normal → Strong downtrend → no entry signal
#       Sector    : Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
#   #35  RALLIS      Fund:30.0  Sec: 4.1  Cap: 4.3  Vol:0.5x
#       Technical : RSI:  21  ADX:  28  → Downtrend ADX 28, no setup yet
#       Volume    : Very Low → Very low volume → no interest, wait
#       Sector    : Downtrend ↓ | RSI 22.6 | ADX 45.2 | Below EMA200
#
# ──────────────────────────────────────────────────────────────────────────────
#   LONG BASE WATCH  (8 stocks, 300+ days)
#   Watch for breakout above range high with 2x+ volume
# ──────────────────────────────────────────────────────────────────────────────
#   Symbol       Category       Fund  Sec    Cap    Days   Range%  ToBreak  Vol    Status
#   ─────────────────────────────────────────────────────────────────────────────────────
#   FINEORG      Mid Cap        73.0  10.0  10.0   798d   37.4%   -21.6% 0.6x  Early stage
#   RELIANCE     Large Cap      55.0  10.0  10.0   606d   34.9%   -11.5% 1.8x  Approaching
#   SUNPHARMA    Large Cap      65.0  10.0  10.0   520d   26.1%    -2.7% 1.8x  NEAR BREAKOUT
#   SUPRAJIT     Mid Cap        45.0  10.0  10.0   491d   39.0%   -24.2% 0.9x  Early stage
#   HAL          Large Cap      62.0   9.1   9.1   484d   49.8%   -23.9% 1.1x  Early stage
#   IPCALAB      Mini Large Cap 53.0   8.2  10.0   481d   37.8%    -3.2% 2.9x  NEAR BREAKOUT
#   GRANULES     Mid Cap        60.0   9.2  10.0   440d   47.9%   -15.7% 1.1x  Early stage
#   PERSISTENT   Mini Large Cap 80.0  10.0  10.0   383d   36.4%   -28.1% 0.8x  Early stage
#
# ──────────────────────────────────────────────────────────────────────────────
#   L=Large Cap  ML=Mini Large Cap  M=Mid Cap  S=Small Cap
#   SecRank = rank vs same sector | CapRank = rank vs same sector + cap
# ──────────────────────────────────────────────────────────────────────────────
#
# Saved: data/technical_report.csv ✅

# %%
# ── Fix 1: Calculate 5-day avg volume ratio from price_data ───────────────────
print("Calculating 5-day average volume ratios...")

vol_5d_data = {}
for symbol, df in price_data.items():
    try:
        vol_5d_avg  = df['Volume'].iloc[-5:].mean()   # last 5 days avg
        vol_20d_avg = df['Volume'].iloc[-20:].mean()  # last 20 days avg
        vol_5d_ratio = vol_5d_avg / vol_20d_avg if vol_20d_avg > 0 else 1.0
        vol_5d_data[symbol] = round(vol_5d_ratio, 2)
    except:
        vol_5d_data[symbol] = 1.0

# Add to tech_df
tech_df['Vol 5D Ratio'] = tech_df['Symbol'].map(vol_5d_data)

# Verify — compare daily vs 5d for key stocks
print(f"\n{'Symbol':12} {'Daily Vol (today)':20} {'5D Avg Vol':20}  Difference")
print("─" * 70)
for _, row in tech_df.iterrows():
    daily = row['Vol Ratio']
    fived = row['Vol 5D Ratio']
    diff  = fived - daily
    flag  = " ← spike" if abs(diff) > 0.5 else ""
    print(f"  {row['Symbol']:12} {daily:6.2f}x (today)          "
          f"{fived:6.2f}x (5d avg)        {diff:+.2f}{flag}")
# Out:
# Calculating 5-day average volume ratios...
#
# Symbol       Daily Vol (today)    5D Avg Vol            Difference
# ──────────────────────────────────────────────────────────────────────
#   TCS            0.61x (today)            0.78x (5d avg)        +0.17
#   RELIANCE       1.09x (today)            1.30x (5d avg)        +0.21
#   WIPRO          0.69x (today)            1.09x (5d avg)        +0.40
#   PERSISTENT     0.49x (today)            0.62x (5d avg)        +0.13
#   LTTS          10.78x (today)            2.35x (5d avg)        -8.43 ← spike
#   HAPPSTMNDS     0.72x (today)            3.69x (5d avg)        +2.97 ← spike
#   CHOLAFIN       0.85x (today)            0.95x (5d avg)        +0.10
#   MUTHOOTFIN     1.17x (today)            0.87x (5d avg)        -0.30
#   MANAPPURAM     0.64x (today)            0.91x (5d avg)        +0.27
#   CREDITACC      0.73x (today)            0.76x (5d avg)        +0.03
#   GARFIBRES      3.65x (today)            1.51x (5d avg)        -2.14 ← spike
#   SUPRAJIT       0.78x (today)            0.73x (5d avg)        -0.05
#   HIMATSEIDE     1.39x (today)            1.56x (5d avg)        +0.17
#   HAL            1.12x (today)            0.83x (5d avg)        -0.29
#   BEL            1.05x (today)            0.98x (5d avg)        -0.07
#   MIDHANI        1.22x (today)            1.02x (5d avg)        -0.20
#   PARAS          0.28x (today)            0.66x (5d avg)        +0.38
#   VINATIORGA     1.56x (today)            1.16x (5d avg)        -0.40
#   FINEORG        0.44x (today)            0.50x (5d avg)        +0.06
#   GALAXYSURF     1.29x (today)            0.74x (5d avg)        -0.55 ← spike
#   AAVAS          0.64x (today)            1.10x (5d avg)        +0.46
#   SUNPHARMA      1.05x (today)            1.23x (5d avg)        +0.18
#   DIVISLAB       0.75x (today)            0.87x (5d avg)        +0.12
#   APLLTD         0.79x (today)            0.92x (5d avg)        +0.13
#   GRANULES       0.71x (today)            0.85x (5d avg)        +0.14
#   IPCALAB        2.91x (today)            1.19x (5d avg)        -1.72 ← spike
#   TITAN          1.35x (today)            1.17x (5d avg)        -0.18
#   HAVELLS        2.26x (today)            1.58x (5d avg)        -0.68 ← spike
#   VGUARD         1.85x (today)            1.50x (5d avg)        -0.35
#   SYMPHONY       0.70x (today)            0.93x (5d avg)        +0.23
#   WONDERLA       1.14x (today)            1.36x (5d avg)        +0.22
#   PIIND          1.13x (today)            0.81x (5d avg)        -0.32
#   RALLIS         0.49x (today)            0.47x (5d avg)        -0.02
#   DHANUKA        0.84x (today)            0.70x (5d avg)        -0.14
#   ABSLAMC        0.44x (today)            2.33x (5d avg)        +1.89 ← spike

# %%
# ── Fix: use non-overlapping baseline ─────────────────────────────────────────
print("Calculating 5-day volume ratio vs prior 15-day baseline...")

vol_5d_data = {}
for symbol, df in price_data.items():
    try:
        if len(df) < 20:
            vol_5d_data[symbol] = 1.0
            continue

        vol_5d_avg      = df['Volume'].iloc[-5:].mean()    # last 5 days
        vol_prior15_avg = df['Volume'].iloc[-20:-5].mean() # prior 15 days (no overlap)

        vol_5d_ratio = vol_5d_avg / vol_prior15_avg if vol_prior15_avg > 0 else 1.0
        vol_5d_data[symbol] = round(vol_5d_ratio, 2)
    except:
        vol_5d_data[symbol] = 1.0

# Update tech_df
tech_df['Vol 5D Ratio'] = tech_df['Symbol'].map(vol_5d_data)

# Compare old vs new
print(f"\n{'Symbol':12} {'Old(vs20D)':12} {'New(vs15D)':12}  Change")
print("─" * 55)
for _, row in tech_df.iterrows():
    old = row['Vol Ratio']        # original daily vs 20D
    new = row['Vol 5D Ratio']     # 5D vs prior 15D
    flag = " ← different" if abs(new - old) > 0.3 else ""
    print(f"  {row['Symbol']:12} {old:6.2f}x       {new:6.2f}x      {flag}")
# Out:
# Calculating 5-day volume ratio vs prior 15-day baseline...
#
# Symbol       Old(vs20D)   New(vs15D)    Change
# ───────────────────────────────────────────────────────
#   TCS            0.61x         0.73x
#   RELIANCE       1.09x         1.44x       ← different
#   WIPRO          0.69x         1.13x       ← different
#   PERSISTENT     0.49x         0.55x
#   LTTS          10.78x         4.29x       ← different
#   HAPPSTMNDS     0.72x        35.76x       ← different
#   CHOLAFIN       0.85x         0.94x
#   MUTHOOTFIN     1.17x         0.83x       ← different
#   MANAPPURAM     0.64x         0.88x
#   CREDITACC      0.73x         0.70x
#   GARFIBRES      3.65x         1.83x       ← different
#   SUPRAJIT       0.78x         0.67x
#   HIMATSEIDE     1.39x         1.93x       ← different
#   HAL            1.12x         0.79x       ← different
#   BEL            1.05x         0.97x
#   MIDHANI        1.22x         1.02x
#   PARAS          0.28x         0.59x       ← different
#   VINATIORGA     1.56x         1.22x       ← different
#   FINEORG        0.44x         0.43x
#   GALAXYSURF     1.29x         0.68x       ← different
#   AAVAS          0.64x         1.14x       ← different
#   SUNPHARMA      1.05x         1.34x
#   DIVISLAB       0.75x         0.83x
#   APLLTD         0.79x         0.90x
#   GRANULES       0.71x         0.80x
#   IPCALAB        2.91x         1.27x       ← different
#   TITAN          1.35x         1.23x
#   HAVELLS        2.26x         1.96x
#   VGUARD         1.85x         1.80x
#   SYMPHONY       0.70x         0.91x
#   WONDERLA       1.14x         1.54x       ← different
#   PIIND          1.13x         0.76x       ← different
#   RALLIS         0.49x         0.40x
#   DHANUKA        0.84x         0.64x
#   ABSLAMC        0.44x         4.20x       ← different

# %%
# ── Rebuild inferences with new 5D vs 15D ratio ───────────────────────────────
for idx, row in tech_df.iterrows():
    label, inference = get_volume_inference(row)
    tech_df.at[idx, 'Vol Label']     = label
    tech_df.at[idx, 'Vol Inference'] = inference

# ── Final verify ──────────────────────────────────────────────────────────────
print(f"{'Symbol':12} {'5D/15D':8} {'Label':12}  Inference")
print("─" * 85)
for _, row in tech_df.iterrows():
    print(f"  {row['Symbol']:12} {row['Vol 5D Ratio']:5.2f}x  "
          f"{row['Vol Label']:12}  {row['Vol Inference']}")
# Out:
# Symbol       5D/15D   Label         Inference
# ─────────────────────────────────────────────────────────────────────────────────────
#   TCS           0.73x  Very Low      Strong downtrend → no entry signal
#   RELIANCE      1.44x  Normal        Low activity → no setup forming yet
#   WIPRO         1.13x  Very Low      Low volume on down move → selling pressure easing
#   PERSISTENT    0.55x  Very Low      Sellers exhausted → reversal likely
#   LTTS          4.29x  Very High     High volume → could be capitulation or distribution
#   HAPPSTMNDS   35.76x  Low           Weak volume → momentum may fade, wait
#   CHOLAFIN      0.94x  Low           Strong downtrend → no entry signal
#   MUTHOOTFIN    0.83x  Normal        Strong downtrend → no entry signal
#   MANAPPURAM    0.88x  Very Low      Strong downtrend → no entry signal
#   CREDITACC     0.70x  Low           Neutral volume → wait for low-volume base to form
#   GARFIBRES     1.83x  Very High     High volume → could be capitulation or distribution
#   SUPRAJIT      0.67x  Low           Neutral volume → wait for low-volume base to form
#   HIMATSEIDE    1.93x  Normal        Strong downtrend → no entry signal
#   HAL           0.79x  Normal        Low activity → no setup forming yet
#   BEL           0.97x  Normal        Low activity → no setup forming yet
#   MIDHANI       1.02x  Normal        Low activity → no setup forming yet
#   PARAS         0.59x  Very Low      Very low volume → no interest, wait
#   VINATIORGA    1.22x  High          High volume → could be capitulation or distribution
#   FINEORG       0.43x  Very Low      Sellers exhausted → reversal likely
#   GALAXYSURF    0.68x  Normal        Low activity → no setup forming yet
#   AAVAS         1.14x  Very Low      Strong downtrend → no entry signal
#   SUNPHARMA     1.34x  Normal        Average volume → monitor for increase
#   DIVISLAB      0.83x  Low           Low activity → no setup forming yet
#   APLLTD        0.90x  Low           Neutral volume → wait for low-volume base to form
#   GRANULES      0.80x  Low           Low activity → no setup forming yet
#   IPCALAB       1.27x  Very High     Strong participation → trend likely to continue
#   TITAN         1.23x  Normal        Low activity → no setup forming yet
#   HAVELLS       1.96x  Very High     High volume → could be capitulation or distribution
#   VGUARD        1.80x  High          Above avg volume but no setup → watch
#   SYMPHONY      0.91x  Low           Low activity → no setup forming yet
#   WONDERLA      1.54x  Normal        Average volume → monitor for increase
#   PIIND         0.76x  Normal        Low activity → no setup forming yet
#   RALLIS        0.40x  Very Low      Very low volume → no interest, wait
#   DHANUKA       0.64x  Low           Low activity → no setup forming yet
#   ABSLAMC       4.20x  Very Low      Very low volume → no conviction, caution

# %%
for idx, row in tech_df.iterrows():
    label, inference = get_volume_inference(row)
    tech_df.at[idx, 'Vol Label']     = label
    tech_df.at[idx, 'Vol Inference'] = inference

print(f"{'Symbol':12} {'5D/15D':8} {'Label':12}  Inference")
print("─" * 85)
for _, row in tech_df.iterrows():
    print(f"  {row['Symbol']:12} {row['Vol 5D Ratio']:5.2f}x  "
          f"{row['Vol Label']:12}  {row['Vol Inference']}")
# Out:
# Symbol       5D/15D   Label         Inference
# ─────────────────────────────────────────────────────────────────────────────────────
#   TCS           0.73x  Very Low      Strong downtrend → no entry signal
#   RELIANCE      1.44x  Normal        Low activity → no setup forming yet
#   WIPRO         1.13x  Very Low      Low volume on down move → selling pressure easing
#   PERSISTENT    0.55x  Very Low      Sellers exhausted → reversal likely
#   LTTS          4.29x  Very High     High volume → could be capitulation or distribution
#   HAPPSTMNDS   35.76x  Low           Weak volume → momentum may fade, wait
#   CHOLAFIN      0.94x  Low           Strong downtrend → no entry signal
#   MUTHOOTFIN    0.83x  Normal        Strong downtrend → no entry signal
#   MANAPPURAM    0.88x  Very Low      Strong downtrend → no entry signal
#   CREDITACC     0.70x  Low           Neutral volume → wait for low-volume base to form
#   GARFIBRES     1.83x  Very High     High volume → could be capitulation or distribution
#   SUPRAJIT      0.67x  Low           Neutral volume → wait for low-volume base to form
#   HIMATSEIDE    1.93x  Normal        Strong downtrend → no entry signal
#   HAL           0.79x  Normal        Low activity → no setup forming yet
#   BEL           0.97x  Normal        Low activity → no setup forming yet
#   MIDHANI       1.02x  Normal        Low activity → no setup forming yet
#   PARAS         0.59x  Very Low      Very low volume → no interest, wait
#   VINATIORGA    1.22x  High          High volume → could be capitulation or distribution
#   FINEORG       0.43x  Very Low      Sellers exhausted → reversal likely
#   GALAXYSURF    0.68x  Normal        Low activity → no setup forming yet
#   AAVAS         1.14x  Very Low      Strong downtrend → no entry signal
#   SUNPHARMA     1.34x  Normal        Average volume → monitor for increase
#   DIVISLAB      0.83x  Low           Low activity → no setup forming yet
#   APLLTD        0.90x  Low           Neutral volume → wait for low-volume base to form
#   GRANULES      0.80x  Low           Low activity → no setup forming yet
#   IPCALAB       1.27x  Very High     Strong participation → trend likely to continue
#   TITAN         1.23x  Normal        Low activity → no setup forming yet
#   HAVELLS       1.96x  Very High     High volume → could be capitulation or distribution
#   VGUARD        1.80x  High          Above avg volume but no setup → watch
#   SYMPHONY      0.91x  Low           Low activity → no setup forming yet
#   WONDERLA      1.54x  Normal        Average volume → monitor for increase
#   PIIND         0.76x  Normal        Low activity → no setup forming yet
#   RALLIS        0.40x  Very Low      Very low volume → no interest, wait
#   DHANUKA       0.64x  Low           Low activity → no setup forming yet
#   ABSLAMC       4.20x  Very Low      Very low volume → no conviction, caution

# %%
def get_volume_inference(row):
    vol   = float(row['Vol 5D Ratio'])  # single source of truth
    setup = str(row['Best Setup'])
    rsi   = float(row['RSI'])
    adx   = float(row['ADX'])

    # ── Label based on 5D ratio ───────────────────────────────────────────────
    if   vol >= 3.0:  vol_label = "Extremely High"
    elif vol >= 2.0:  vol_label = "Very High"
    elif vol >= 1.5:  vol_label = "High"
    elif vol >= 1.0:  vol_label = "Normal"
    elif vol >= 0.7:  vol_label = "Low"
    else:             vol_label = "Very Low"

    # ── Momentum ──────────────────────────────────────────────────────────────
    if setup == 'Momentum':
        if   vol >= 3.0: return vol_label, "Exceptional participation → strong conviction"
        elif vol >= 2.0: return vol_label, "Strong participation → trend likely to continue"
        elif vol >= 1.5: return vol_label, "Good volume support → momentum confirmed"
        elif vol >= 1.0: return vol_label, "Average volume → monitor for increase"
        elif vol >= 0.
# Out:
#   Cell In[21], line 21
#     elif vol >= 0.
#                   ^
# SyntaxError: expected ':'
