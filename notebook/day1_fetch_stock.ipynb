# %%
import pandas as pd
import yfinance as yfinance
import warnings
warnings.filterwarnings('ignore')

# %%
url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
nse_stocks=pd.read_csv(url)

# %%
print(f"Total number of nse_stocks = {len(nse_stocks)}")
# Out:
# Total number of nse_stocks = 2251

# %%
nse_stocks.head(10)
# Out:
#        SYMBOL                           NAME OF COMPANY  SERIES  \
# 0   20MICRONS                        20 Microns Limited      EQ
# 1  21STCENMGM  21st Century Management Services Limited      EQ
# 2      360ONE                       360 ONE WAM LIMITED      EQ
# 3   3IINFOLTD                       3i Infotech Limited      EQ
# 4     3MINDIA                          3M India Limited      EQ
# 5      3PLAND                  3P Land Holdings Limited      EQ
# 6      5PAISA                    5Paisa Capital Limited      EQ
# 7     63MOONS             63 moons technologies limited      EQ
# 8    A2ZINFRA             A2Z Infra Engineering Limited      BE
# 9     AAATECH                  AAA Technologies Limited      EQ
#
#    DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0      06-OCT-2008               5            1  INE144J01027            5
# 1      03-MAY-1995              10            1  INE253B01015           10
# ...

# %%
url_bse="../data/bse_stocks.csv"
bse_stocks=pd.read_csv(url_bse)

# %%
print(f"number of stocks in bse = {len(bse_stocks)}")
# Out:
# number of stocks in bse = 4851

# %%
bse_stocks.head(10)
# Out:
#                                                                                                           Security Code  \
# 500002 ABB India Limited                      ABB        ABB India Ltd                             Active            A
# 500003 Aegis Logistics Ltd.                   AEGISLOG   Aegis Logistics Ltd                       Active            A
# 500008 Amara Raja Energy & Mobility Limited   ARE&M      Amara Raja Energy & Mobility Ltd          Active            A
# 500009 Ambalal Sarabhai Enterprise Ltd.       AMBALALSA  Ambalal Sarabhai Enterprises Ltd          Active            X
# 500012 Andhra Petrochemicals Ltd.             ANDHRAPET  Andhra Petrochemicals Ltd                 Active            X
# 500013 Ansal Properties & Infrastructure Ltd. ANSALAPI   Ansal Properties & Infrastructure Ltd     Active            Z
# 500014 UTIQUE ENTERPRISES LIMITED             UTIQUE     Utique Enterprises Ltd                    Active            X
# ...

# %%
nse_stocks.to_csv("../data/nse_stocks.csv", index='False')

# %%
print(f"Total NSE stocks: {len(nse_stocks)}")
print("Saved to data folder successfully!")
print("\nColumns available:")
# Out:
# Total NSE stocks: 2251
# Saved to data folder successfully!
#
# Columns available:

# %%
print(nse_stocks.columns.tolist())
# Out:
# ['SYMBOL', 'NAME OF COMPANY', ' SERIES', ' DATE OF LISTING', ' PAID UP VALUE', ' MARKET LOT', ' ISIN NUMBER', ' FACE VALUE']

# %%
nse_stocks.columns.to_list()
# Out:
# ['SYMBOL',
#  'NAME OF COMPANY',
#  ' SERIES',
#  ' DATE OF LISTING',
#  ' PAID UP VALUE',
#  ' MARKET LOT',
#  ' ISIN NUMBER',
#  ' FACE VALUE']

# %%
# Add exchange column to identify source
nse_stocks['Exchange'] = 'NSE'
bse_stocks['Exchange'] = 'BSE'

# %%
nse_stocks
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      EQ
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 2246        ZOTA                  Zota Health Care LImited      EQ
# 2247       ZUARI              Zuari Agro Chemicals Limited      EQ
# 2248    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 2249   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 2250   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE  \
# 0         06-OCT-2008               5            1  INE144J01027            5
# ...

# %%
nse_clean=nse_stocks[['SYMBOL', 'NAME OF COMPANY', 'Exchange']].copy()
nse_clean.columns=['Symbol', 'Company Name', 'Exchange']

# %%
nse_clean
# Out:
#           Symbol                              Company Name Exchange
# 0      20MICRONS                        20 Microns Limited      NSE
# 1     21STCENMGM  21st Century Management Services Limited      NSE
# 2         360ONE                       360 ONE WAM LIMITED      NSE
# 3      3IINFOLTD                       3i Infotech Limited      NSE
# 4        3MINDIA                          3M India Limited      NSE
# ...          ...                                       ...      ...
# 2246        ZOTA                  Zota Health Care LImited      NSE
# 2247       ZUARI              Zuari Agro Chemicals Limited      NSE
# 2248    ZUARIIND                  ZUARI INDUSTRIES LIMITED      NSE
# 2249   ZYDUSLIFE                Zydus Lifesciences Limited      NSE
# 2250   ZYDUSWELL                    Zydus Wellness Limited      NSE
#
# [2251 rows x 3 columns]

# %%
bse_stocks = pd.read_csv("../data/bse_stocks.csv", index_col=False)

# %%
bse_stocks
# Out:
#       Security Code                           Issuer Name Security Id  \
# 0            500002                     ABB India Limited         ABB
# 1            500003                  Aegis Logistics Ltd.    AEGISLOG
# 2            500008  Amara Raja Energy & Mobility Limited       ARE&M
# 3            500009      Ambalal Sarabhai Enterprise Ltd.   AMBALALSA
# 4            500012            Andhra Petrochemicals Ltd.   ANDHRAPET
# ...             ...                                   ...         ...
# 4846         890228            Allcargo Terminals Limited       ATLPP
# 4847         890230             Ace Software Exports ltd.     ACESEPP
# 4848         890231               ANIRIT VENTURES LIMITED    ANIRITPP
# 4849         890232               KRISHIVAL FOODS LIMITED     KRISHPP
# 4850         890233                     PVV Infra Limited      PVVIPP
#
#                          Security Name  Status Group  Face Value  \
# ...

# %%
bse_stocks['Exchange'] = 'BSE'

# %%
bse_clean = bse_stocks[['Security Id', 'Issuer Name', 'Exchange']].copy()
bse_clean.columns = ['Symbol', 'Company Name', 'Exchange']

print(f"BSE stocks: {len(bse_clean)}")
print(bse_clean.head(5))
# Out:
# BSE stocks: 4851
#       Symbol                          Company Name Exchange
# 0        ABB                     ABB India Limited      BSE
# 1   AEGISLOG                  Aegis Logistics Ltd.      BSE
# 2      ARE&M  Amara Raja Energy & Mobility Limited      BSE
# 3  AMBALALSA      Ambalal Sarabhai Enterprise Ltd.      BSE
# 4  ANDHRAPET            Andhra Petrochemicals Ltd.      BSE

# %%
# Combine both
master_list = pd.concat([nse_clean, bse_clean], ignore_index=True)
master_list
# Out:
#           Symbol                              Company Name Exchange
# 0      20MICRONS                        20 Microns Limited      NSE
# 1     21STCENMGM  21st Century Management Services Limited      NSE
# 2         360ONE                       360 ONE WAM LIMITED      NSE
# 3      3IINFOLTD                       3i Infotech Limited      NSE
# 4        3MINDIA                          3M India Limited      NSE
# ...          ...                                       ...      ...
# 7097       ATLPP                Allcargo Terminals Limited      BSE
# 7098     ACESEPP                 Ace Software Exports ltd.      BSE
# 7099    ANIRITPP                   ANIRIT VENTURES LIMITED      BSE
# 7100     KRISHPP                   KRISHIVAL FOODS LIMITED      BSE
# 7101      PVVIPP                         PVV Infra Limited      BSE
#
# [7102 rows x 3 columns]

# %%
# Save to data folder
master_list.to_csv("../data/master_stocks.csv", index=False)

print(f"NSE stocks:     {len(nse_clean)}")
print(f"BSE stocks:     {len(bse_clean)}")
print(f"Total universe: {len(master_list)}")
master_list.head(5)
# Out:
# NSE stocks:     2251
# BSE stocks:     4851
# Total universe: 7102
#        Symbol                              Company Name Exchange
# 0   20MICRONS                        20 Microns Limited      NSE
# 1  21STCENMGM  21st Century Management Services Limited      NSE
# 2      360ONE                       360 ONE WAM LIMITED      NSE
# 3   3IINFOLTD                       3i Infotech Limited      NSE
# 4     3MINDIA                          3M India Limited      NSE
